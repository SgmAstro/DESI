# %%
import os
import sys
import glob
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import numpy as np

from   mpl_toolkits.axes_grid1 import make_axes_locatable
from   astropy.table           import Table

# %%
os.environ['CODE_ROOT'] = os.environ['HOME'] + '/DESI/'

sys.path.append(os.environ['CODE_ROOT'])

# %%
from   gama_limits import gama_field
from   delta8_limits import delta8_tier

# %%
field = 'G9'

# %%
gama_d8 = Table.read(os.environ['HOME'] + '/data/GAMA4/gama_gold_ddp_n8.fits')
gama_d8
# Out:
# <Table length=113687>
#  CATAID       OBJID             RA          DEC      R_PETRO   ZGAMA  ... DDP1_N8 DDP2_N8 DDP3_N8     DDP1_DELTA8          DDP2_DELTA8          DDP3_DELTA8
#                                deg          deg        mag            ...
#  int32        int64          float64      float64    float32  float32 ...  int64   int64   int64        float64              float64              float64
# ------- ------------------ ------------ ----------- --------- ------- ... ------- ------- ------- -------------------- -------------------- --------------------
#  209748 587725074990104938 134.80169161  0.00541943 17.670448 0.16614 ...      13      36       0   1.3130009079623144    2.473270943092479                 -1.0
#  537129 588848898840789129 184.21539209 -1.03669489 16.961576 0.07156 ...      26      48      83   1.5418662609606906   1.5446279751498584   1.3746341106786835
#  382081 587727944027472289 135.23306993  1.95568309 19.110462 0.22654 ...       9       0       0    1.165499853648257                 -1.0                 -1.0
#  561801 588848899377922344 184.87290284 -0.54973036  19.31083 0.23925 ...      30       0       0   1.5124224331476621                 -1.0                 -1.0
#  227206 587726014009442667 212.57882544  1.21256973 19.320875 0.25749 ...       0       0       0                 -1.0                 -1.0                 -1.0
#  363681 587726033340137638 220.75196667  2.46013928 18.085209 0.12255 ...      18      20       0    3.148302449172343   1.4993761128953325                 -1.0
#  209284 587725074989187472 132.63681292  0.13970627 19.025364 0.21044 ...       7       0       0  0.24070835550415404                 -1.0                 -1.0
#  125782 587724649259532757 185.68473966 -2.62397534 19.746466 0.06787 ...      17      20      42   3.0380818526967497   1.5760833081760075   1.9195421383563769
#  301084 587726032227533257 131.94779532  1.26155398 18.989965 0.18865 ...      10       0       0    1.594298396983945                 -1.0                 -1.0
#  609191 588848900446945574 174.12463152  0.30731137 18.572287 0.20661 ...      17       0       0   1.7458956598337894                 -1.0                 -1.0
#  726327 587727943492043097 138.51169658  1.64436206  19.14496 0.16643 ...      44      60       0    13.69977998175939    9.869588922627543                 -1.0
#   62937 587722982828671232 213.97411007 -0.37978763 19.479546 0.18397 ...      70      19       0   11.266626005361823   0.8054455562678831                 -1.0
#  123741 587724649255731557  177.0248117  -2.5957784 19.130035 0.16723 ...      29      51       0   3.3512125941013444   3.1494085014812416                 -1.0
# 3575143 587729150373986686 129.14796243 -1.50048529 17.739622 0.10811 ...      18      27       0    3.931462793558863   3.0111668856068015                 -1.0
#  549846 588848899355312600 133.18212791 -0.62478833 19.526155 0.24393 ...       8       0       0   0.3315538725738387                 -1.0                 -1.0
# 3554388 587729149837705905 130.41865596 -1.96058162 19.461157 0.21259 ...      20       0       0   3.0735036233344406                 -1.0                 -1.0
# %%
# gama_d8 = gama_d8[gama_d8['FILLFACTOR'] > 0.8]

# %%
bins=np.arange(-1., 150., 1.)

_ = pl.hist(gama_d8['DDP1_N8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_N8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_N8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$N_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
bins=np.arange(-1., 10., 0.1)

_ = pl.hist(gama_d8['DDP1_DELTA8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_DELTA8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_DELTA8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$\delta_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 35))

for idx, ax in enumerate(axes):
    sc = ax.scatter(gama_d8['MCOLOR_0P0'], gama_d8['DDP1_DELTA8'], c=gama_d8['DDP1_N8'], marker='.', lw=0.0, s=12)

    ax.set_xlabel('MCOLOR_0P0')
    ax.set_ylabel('DDP1_DELTA8')

    ax.set_xlim(-23., -16.)
    ax.set_ylim(-1.1, 1.)
    
    ax.spines['top'].set_visible(False)
    
    divider = make_axes_locatable(ax)
    
    axLog = divider.append_axes("top", size=5.0, pad=0, sharex=ax)
    axLog.set_yscale('log')
    axLog.set_xlim((-16., -23.))
    axLog.set_ylim((1., 50.))
    axLog.scatter(gama_d8['MCOLOR_0P0'], gama_d8['DDP1_DELTA8'], c=gama_d8['DDP1_N8'], marker='.', lw=0.0, s=12)

    axLog.spines['bottom'].set_visible(False)
    axLog.xaxis.set_ticks_position('top')
    axLog.xaxis.set_visible(False)

    axLog.set_yticks([10.])
    axLog.set_yticklabels(['10'])
    
    ax.set_title('DDP{}'.format(idx+1))

    colorbar = fig.colorbar(sc, ax=ax, label=r'$N_8$')

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 30))

gama_d8_slice = gama_d8[np.abs(gama_d8['CARTESIAN_Z']) < 5.]

for idx in range(3):
    sc = axes[idx].scatter(gama_d8_slice['CARTESIAN_X'],\
                           gama_d8_slice['CARTESIAN_Y'],\
                           c=gama_d8_slice['DDP{}_DELTA8'.format(idx+1)],\
                           marker='.',\
                           lw=0.0,\
                           s=3,\
                           vmin=-1.,\
                           vmax=10.)
    
    # axes[idx].set_ylim(100., -100.)
    
    colorbar = fig.colorbar(sc, ax=axes[idx], label=r'$\delta_8$')    
    
    axes[idx].set_xlabel('x [Mpc/h]')
    axes[idx].set_ylabel('y [Mpc/h]')
    
    axes[idx].set_title('DDP{}'.format(idx+1))

# %%
tiers = delta8_tier(gama_d8['DDP1_DELTA8'])

# %%
np.unique(tiers, return_counts=True)
# Out:
# (array([-99,   0,   1,   2,   3]), array([13480,  3118,  1302,  3617, 12843]))

# %% [markdown]
# # Done.
