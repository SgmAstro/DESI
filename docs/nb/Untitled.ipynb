# %%
import pubplot
import matplotlib
import matplotlib.pyplot as plt

# %%
nice_fonts = {
    "text.usetex": True,
    "font.family": "serif",
    "font.size"    : 14,
    "font.serif" : "Times New Roman",
}

matplotlib.rcParams.update(nice_fonts)

# %%
plt.plot([1,2], [3,4])
plt.xlabel('Testing')
plt.title('TEST')
# Out:
# Text(0.5, 1.0, 'TEST')
