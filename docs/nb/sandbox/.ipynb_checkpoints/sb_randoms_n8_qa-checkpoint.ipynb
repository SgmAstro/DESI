# %%
import os
import sys
import fitsio
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib as mpl

from   astropy.table import Table
from   scipy.stats   import norm

# %%
repo_root = os.environ['HOME'] + '/DESI/'

sys.path.append(repo_root)

# %%
import pubplot

from   cosmo         import cosmo, fsky
from   cartesian     import rotate

# %%
# update pytest

field  = 'G9'
dryrun = False
realz  = 0
version = 'v1' # 'GAMA4'

# %%
home  = os.environ['HOME']
home  = '/cosma/home/durham/dc-moor2/'

fpath = home + '/data/{}/randoms/randoms_{}_{}.fits'.format(version, field, realz)
rand  = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 2531909),
#              ('FIELD', 'G9'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 1.0),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 2144.660584850632),
#              ('NRAND8_PERR', 46.31048029172913)])

# %%
fpath = home + '/data/{}/randoms/randoms_N8_{}_{}.fits'.format(version, field, realz)
rand  = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 2531909),
#              ('FIELD', 'G9'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 1.0),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 2144.660584850632),
#              ('NRAND8_PERR', 46.31048029172913),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7766460011003555)])

# %%
fpath = home + '/data/{}/randoms/randoms_bd_{}_{}.fits'.format(version, field, realz)

if dryrun:
    fpath = fpath.replace('.fits', '_dryrun.fits')

rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 2531909),
#              ('FIELD', 'G9'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 1.0),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 2144.660584850632),
#              ('NRAND8_PERR', 46.31048029172913),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7766460011003555)])

# %%
rand
# Out:
# <Table length=2531909>
# RANDOM_RA RANDOM_DEC      Z          V       RANDID FIELD  CARTESIAN_X CARTESIAN_Y ...    ROTCARTESIAN_Y       ROTCARTESIAN_Z    IS_BOUNDARY RAND_N8      FILLFACTOR         BOUND_DIST     BOUND_ID
#  float32   float32     float32    float32    int64  bytes4   float32     float32   ...       float64              float64           int64     int32        float64            float64        int64
# --------- ---------- ----------- ---------- ------- ------ ----------- ----------- ... ------------------- --------------------- ----------- ------- ------------------- ------------------ --------
# 129.91917  0.9630972  0.17833136  836733.75 1033339     G9   -331.0364     395.646 ... -45.647413200102214     4.211200499007996           0    2121  0.9889676786071583  7.254431862020988  1862828
#  134.6177 -0.5850006  0.24175805  2001640.9  277242     G9   -484.6323     491.143 ...  -4.552118400989399   -13.034564401493304           0    2191                 1.0  16.51122748603918   179421
# 138.14908  0.5982364   0.2318685  1777287.4 2015130     G9  -493.99463   442.47278 ...  36.481019130586894    1.1761021336778024           0    2130                 1.0  27.23674006160685  1882340
# 129.85628  1.6507276  0.21484718  1429525.0  167734     G9  -395.11298   473.28323 ...  -55.22875291473468    12.436378044268508           0    2116  0.9866363073704606  7.962683501090891  1145194
# 137.84189 0.65900105  0.18979728  1001433.6  620978     G9   -406.0459    367.6393 ...   27.19850999004637    1.5510219653376476           0    2155                 1.0 21.965019684610855  2299144
#  136.4454 -1.2915285   0.0738935  63461.688  127288     G9  -158.23444   150.44571 ...  5.5238006534409285    -6.817103322452513           0    1522  0.7096694044507755 2.7167478710942414  1850872
#  133.5719   2.983789  0.20031433  1169448.5 1147770     G9  -397.06546   417.36942 ... -14.313954429858823    25.026774726701294           1    1112  0.5184969630415653                0.0        0
# 135.72247 -0.6331526   0.1450767  459970.44 1443865     G9  -302.58542   295.04907 ...   5.360635778716527     -8.33874561467107           0    2147                 1.0  9.855697324566338  1805739
# 131.47552  1.0984006  0.14652121  473423.06 1362489     G9  -282.57245   319.66513 ...  -26.19660904421195     4.483189535852952           0    2184                 1.0 13.941318741591584   998460
# 133.63914  2.8961444  0.20463307  1243295.2  494119     G9  -405.78476    425.5334 ... -13.920384306284005     24.64291902159325           0    1279   0.596364762347268  1.328501909631038  1883848
# 135.77596  0.4939792  0.09946912  152445.19 1781861     G9  -209.59511   203.99353 ...  3.9828057745934298 -0.017153679252525755           0    2118                 1.0 12.613615645230064  1078532
# 136.69154  0.4568469    0.206353  1273506.6 1898261     G9  -431.84418   407.06967 ...  17.562626449099806   -0.4176492843708832           0    2204                 1.0  25.00215394823015  1372937
# 131.15813  2.0313892  0.20660807  1278026.5 1636481     G9  -390.80786   447.07498 ... -39.742511250187526    15.917899430979777           0    2125                 1.0  9.639335157817742   680984
# 139.79533   2.930614   0.0767862   71088.04  623454     G9  -173.00143   146.22168 ...  18.953043240348276     9.636317452813156           0    1004  0.4681393443288953 0.5744460934088165   620074
# 129.00423 0.96540636   0.0895708 111977.984  772585     G9  -166.07294    205.0521 ...  -27.54278133087298    2.1682059029561103           1    1013 0.47233581255495116                0.0        0
# 138.94278 -1.0413139 0.071656205  57946.957 2473557     G9  -159.73955   139.13982 ...  14.582030104712983    -5.684962852973829           0    1746  0.8141148358548319 3.3874379649165354  1943556
# 131.83571 -1.3501878  0.21956661  1521187.9 1510645     G9  -419.89038   469.03323 ... -34.702191647191505   -20.293580948915043           0    2169                 1.0  6.828908693362664  1163223
# 130.67296 -1.4828467  0.25146925  2238449.2 1242003     G9   -466.6416     543.039 ...  -53.96767474314856   -24.731520389323425           0    2064  0.9623900465088047  6.113792862820604   279619
# 131.21875  2.9117007  0.23042893  1746016.2 1701751     G9   -433.8802    495.2902 ... -43.374246844349265      27.7859184925777           0    1284  0.5986961335839657 0.9256591320933903   459460
# 129.70949  2.2600267  0.19337185  1056685.2  446409     G9   -356.0235   428.68787 ...  -51.33993047122751    17.174347918497006           0    2086  0.9726480799502746  5.887899749086246   691590
# 133.81342 -0.8392051  0.24099058  1983628.8 2008311     G9  -476.22687   496.37213 ... -14.193370681629288   -16.045768698619327           0    2190                 1.0 13.600193343584502  1242246
#  135.6704 -1.7848574  0.25087327  2223437.8 1169014     G9  -510.94812    499.1291 ...     8.4107824099716    -28.45757660866679           0    1557  0.7259890031076593 2.3033170483867975  1569000
#       ...        ...         ...        ...     ...    ...         ...         ... ...                 ...                   ...         ...     ...                 ...                ...      ...
# 131.81554 -1.9346269  0.26231557  2522776.0  524567     G9  -496.67245    555.1947 ...  -41.32580014072965   -31.618454083525474           1     862 0.40192840120668105                0.0        0
# 137.97908  1.3880963  0.19368026  1061541.0 1249359     G9  -414.81442    373.7749 ...  29.061064781830904     8.689119006996304           0    2208                 1.0 15.281222342807009  1477932
# 130.57869 0.14544259  0.07825468  75179.414  856608     G9  -150.31824   175.51134 ... -17.796964897386697   -1.4134854967299157           0    2076  0.9679853374768792  6.368157595723394   217876
# 139.84929   1.720486  0.22198181  1569495.4 1463049     G9   -486.1334   410.09818 ...   53.81245713219965    13.601835902717937           0    2117                 1.0 11.708768732114654  1550684
# 138.06766  1.1760072  0.20615931  1270081.5  861528     G9  -441.02054   396.15463 ...  31.769299664311514     7.030198398710935           0    2129                 1.0  18.39495743550256   913456
#  132.3451    1.71261  0.22288561  1587818.1 1030504     G9   -430.0739    471.8984 ... -29.526639423415244    13.552831710019111           0    2168                 1.0 13.904150617278171  2044638
#  131.4795   1.048748  0.08011387   80576.84 2035150     G9  -156.61185   177.14513 ... -14.501554577050184     2.279570899567999           0    2196                 1.0  8.056128932511475  2325289
# 138.59918 -1.7601296  0.20769303  1297364.4 2325265     G9  -447.72107   394.73062 ...   37.51449785549453    -23.51250514332178           0    1506   0.702209016493343 2.5030231127725378   138001
# 136.07568  -1.229926  0.26150495  2500790.5  780515     G9   -535.1614   515.43506 ...  14.004223848216439    -22.40049296548772           0    1830   0.853281872631353 1.6591339485007632  2031640
# 138.41817 -1.3063016   0.2582956  2414921.0  814805     G9  -549.32965    487.4064 ...  43.841225403661944    -23.10961075695954           0    2117                 1.0  8.420048282589047   778384
# 130.84155  1.5858226  0.17627648   809189.0 2151555     G9   -333.5386   385.84216 ...  -36.94612226047851     9.703547919915483           0    2101                 1.0 12.200741119537668  1622326
# 131.62756  0.7766683   0.2351386  1849623.4  569627     G9  -446.42447   502.33298 ...  -39.48306539155657    3.2861432856697794           0    2143                 1.0  25.64377091938933  1928399
# 138.15796 -1.7946677   0.1413273  426209.47 2507146     G9  -306.81848    274.7328 ...   22.71879409291432     -16.4736110380562           0    1388  0.6471886553072775  1.328729044309691  1251754
# 133.69719 -1.2208219   0.1758418  803437.75  963678     G9  -351.56506   367.92798 ... -11.532243783667296    -15.26082660359561           0    2051  0.9563284812933908  6.768905071821283  1190699
# 137.58282  2.8860147  0.21549188  1441834.5 1276131     G9  -456.06952   416.69946 ...  27.885031207664948     25.78512604454141           0    1275  0.5944996653579099  1.043253289656174  1100776
# 129.81128  1.1817166  0.24857354  2166101.5  994756     G9   -453.4847    544.0714 ...  -64.00166712089508     8.486340664442512           0    2147                 1.0  8.753942133395073  1045958
# 137.76787  1.6455553   0.2530374  2278250.2 2122150     G9   -533.2233   484.04248 ...   34.82995658278161     14.44375025977088           0    2176                 1.0  16.55554444426001   823099
# 140.57771  1.4497318   0.2587554  2427109.0 2145277     G9   -568.2247   467.11536 ...   71.54988419721677    12.260110879997075           0    1994  0.9297508491950371  4.050606000726118  2292625
# 137.61891 0.07975347  0.20624402  1271578.9  464925     G9  -438.16815   399.83743 ...   27.14826875323541    -4.318283949887302           0    2174                 1.0 21.013623999718817   451204
# 132.72455  1.7985798  0.18364118   910661.7 2035260     G9   -359.8959   389.68036 ...  -21.02111284290032    12.055074387290436           0    2144                 1.0 10.859549957327204  1553858
# 130.51749 -1.8291621  0.20930749  1326481.9 2489519     G9   -390.6463    457.1055 ...  -46.94887605541293   -24.405742944476593           0    1413   0.658845511490766 1.7482311524592777  1503838
# 136.71318 -1.5657755  0.12938984  329488.47 1771023     G9  -275.17746   259.19464 ...  11.329844889950037   -13.613028192923874           0    1612  0.7516340867113339 2.8969510554596702   542435

# %%
fpath = home + '/data/{}/randoms/randoms_bd_ddp_n8_{}_{}.fits'.format(version, field, realz)

if dryrun:
    fpath = fpath.replace('.fits', '_dryrun.fits')

rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 2531909),
#              ('FIELD', 'G9'),
#              ('AREA', 180.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 1.0),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 2144.660584850632),
#              ('NRAND8_PERR', 46.31048029172913),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7766460011003555),
#              ('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1ZLIMS_NGAL', 113687),
#              ('DDP1_NGAL', 45293),
#              ('DDP1_DENS', 0.005963721679858641),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2ZLIMS_NGAL', 73942),
#              ('DDP2_NGAL', 33396),
#              ('DDP2_DENS', 0.01057953807776663),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3ZLIMS_NGAL', 18121),
#              ('DDP3_NGAL', 8842),
#              ('DDP3_DENS', 0.01931329953669401),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('D80LIMS', '[-1.0, -0.75]'),
#              ('D81LIMS', '[-0.75, -0.55]'),
#              ('D82LIMS', '[-0.55, -0.4]'),
#              ('D83LIMS', '[-0.4, 0.0]'),
#              ('D84LIMS', '[0.0, 0.7]'),
#              ('D85LIMS', '[0.7, 1.6]'),
#              ('D86LIMS', '[1.6, 2.9]'),
#              ('D87LIMS', '[2.9, 4.0]'),
#              ('D88LIMS', '[4.0, 10000.0]'),
#              ('DDP1_d0_VOLFRAC', 0.2879104063150402),
#              ('DDP1_d0_TIERMEDd8', -0.9207558941496925),
#              ('DDP1_d1_VOLFRAC', 0.1146066510323285),
#              ('DDP1_d1_TIERMEDd8', -0.6657531003735868),
#              ('DDP1_d2_VOLFRAC', 0.08247686153498549),
#              ('DDP1_d2_TIERMEDd8', -0.4835302012959428),
#              ('DDP1_d3_VOLFRAC', 0.1611691704123112),
#              ('DDP1_d3_TIERMEDd8', -0.2181488802297873),
#              ('DDP1_d4_VOLFRAC', 0.1731655031764409),
#              ('DDP1_d4_TIERMEDd8', 0.2747642477954721),
#              ('DDP1_d5_VOLFRAC', 0.1076667903035503),
#              ('DDP1_d5_TIERMEDd8', 1.032812911402553),
#              ('DDP1_d6_VOLFRAC', 0.05214158437703798),
#              ('DDP1_d6_TIERMEDd8', 2.049219367103829),
#              ('DDP1_d7_VOLFRAC', 0.01311459480085179),
#              ('DDP1_d7_TIERMEDd8', 3.300181158736169),
#              ('DDP1_d8_VOLFRAC', 0.007748438047453653),
#              ('DDP1_d8_TIERMEDd8', 4.785698286299573),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
pl.plot(rand['RANDOM_RA'][::10], rand['RANDOM_DEC'][::10], marker=',', lw=0.0, c='k')
pl.plot(rand['RANDOM_RA'][rand['IS_BOUNDARY'].astype(bool)], rand['RANDOM_DEC'][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='cyan')

pl.xlabel('RA [deg.]')
pl.ylabel('DEC [deg.]')
# Out:
# Text(0, 0.5, 'DEC [deg.]')

# %%
_ = pl.hist(rand['V'], bins=100, histtype='step', color='k')
_ = pl.hist(rand['V'][rand['IS_BOUNDARY'].astype(bool)], bins=100, histtype='step', color='c')

pl.xlabel('V')
# Out:
# Text(0.5, 0, 'V')

# %%
_ = pl.hist(rand['Z'], bins=100, histtype='step', color='k')

pl.axvline(300. / 2.9979e5, lw=0.5, c='k')

pl.yscale('log')
pl.xlabel('$z$')

pl.xlim(0.0, 0.6)
# Out:
# (0.0, 0.6)

# %%
pos = np.c_[rand['CARTESIAN_X'], rand['CARTESIAN_Y'], rand['CARTESIAN_Z']]
pos = rotate(rand['RANDOM_RA'], rand['RANDOM_DEC'], pos)

# %%
pl.plot(pos[::10,0], pos[::10,1], marker=',', lw=0.0, c='k')

pl.xlabel('$x$')
pl.ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
pl.plot(pos[:,0][rand['IS_BOUNDARY'].astype(bool)], pos[:,1][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='k')

pl.xlabel('$x$')
pl.ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(pos[::10, 0],\
           pos[::10, 1],\
           pos[::10, 2],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(pos[:,0][rand['IS_BOUNDARY'].astype(bool)][::10],\
           pos[:,1][rand['IS_BOUNDARY'].astype(bool)][::10],\
           pos[:,2][rand['IS_BOUNDARY'].astype(bool)][::10],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
np.mean(rand['V'] < np.percentile(rand['V'], 1.))
# Out:
# 0.010000359412601321

# %%
np.mean(rand['IS_BOUNDARY'].data)
# Out:
# 0.05877027965855013

# %%
rand.dtype.names
# Out:
# ('RANDOM_RA',
#  'RANDOM_DEC',
#  'Z',
#  'V',
#  'RANDID',
#  'FIELD',
#  'CARTESIAN_X',
#  'CARTESIAN_Y',
#  'CARTESIAN_Z',
#  'ROTCARTESIAN_X',
#  'ROTCARTESIAN_Y',
#  'ROTCARTESIAN_Z',
#  'IS_BOUNDARY',
#  'RAND_N8',
#  'FILLFACTOR',
#  'BOUND_DIST',
#  'BOUND_ID',
#  'DDP1_N8',
#  'DDP2_N8',
#  'DDP3_N8',
#  'IN_DDP1',
#  'IN_DDP2',
#  'IN_DDP3',
#  'DDP1_DELTA8',
#  'DDP2_DELTA8',
#  'DDP3_DELTA8',
#  'DDP1_DELTA8_TIER')

# %%
rand['RAND_N8'].data.min(), rand['RAND_N8'].data.max()
# Out:
# (290, 2341)

# %%
_ = pl.hist(rand['RAND_N8'], bins=np.arange(0, 3500, 1), histtype='step')

pl.axvline(rand.meta['NRAND8'], c='k', lw=0.5)

pl.xlabel(r'$N_8$')
pl.xlim(50., 2500.)
# Out:
# (50.0, 2500.0)

# %%
rand.meta['NRAND8']
# Out:
# 2144.660584850632

# %%
# 100. * np.sqrt(rand.meta['NRAND8']) / rand.meta['NRAND8']

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(pos[:,0][isin], pos[:,1][isin], lw=0.0, c=rand['V'][isin], s=2)
pl.xlabel('$x$')
pl.ylabel('$y$')
pl.colorbar(label='V')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(pos[:,0][isin], pos[:,1][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('$x$')
pl.ylabel('$y$')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(pos[:,1][isin], pos[:,2][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('$y$')
pl.ylabel('$z$')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(pos[:,0][isin], pos[:,1][isin], lw=0.0, c=rand['RAND_N8'][isin], vmin=0, vmax=1500, s=2)
pl.xlabel('$x$')
pl.ylabel('$y$')
pl.colorbar(label=r'$N_8$')

# %%
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 2531909),
#              ('FIELD', 'G9'),
#              ('AREA', 180.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 1.0),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 2144.660584850632),
#              ('NRAND8_PERR', 46.31048029172913),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7766460011003555),
#              ('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1ZLIMS_NGAL', 113687),
#              ('DDP1_NGAL', 45293),
#              ('DDP1_DENS', 0.005963721679858641),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2ZLIMS_NGAL', 73942),
#              ('DDP2_NGAL', 33396),
#              ('DDP2_DENS', 0.01057953807776663),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3ZLIMS_NGAL', 18121),
#              ('DDP3_NGAL', 8842),
#              ('DDP3_DENS', 0.01931329953669401),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('D80LIMS', '[-1.0, -0.75]'),
#              ('D81LIMS', '[-0.75, -0.55]'),
#              ('D82LIMS', '[-0.55, -0.4]'),
#              ('D83LIMS', '[-0.4, 0.0]'),
#              ('D84LIMS', '[0.0, 0.7]'),
#              ('D85LIMS', '[0.7, 1.6]'),
#              ('D86LIMS', '[1.6, 2.9]'),
#              ('D87LIMS', '[2.9, 4.0]'),
#              ('D88LIMS', '[4.0, 10000.0]'),
#              ('DDP1_d0_VOLFRAC', 0.2879104063150402),
#              ('DDP1_d0_TIERMEDd8', -0.9207558941496925),
#              ('DDP1_d1_VOLFRAC', 0.1146066510323285),
#              ('DDP1_d1_TIERMEDd8', -0.6657531003735868),
#              ('DDP1_d2_VOLFRAC', 0.08247686153498549),
#              ('DDP1_d2_TIERMEDd8', -0.4835302012959428),
#              ('DDP1_d3_VOLFRAC', 0.1611691704123112),
#              ('DDP1_d3_TIERMEDd8', -0.2181488802297873),
#              ('DDP1_d4_VOLFRAC', 0.1731655031764409),
#              ('DDP1_d4_TIERMEDd8', 0.2747642477954721),
#              ('DDP1_d5_VOLFRAC', 0.1076667903035503),
#              ('DDP1_d5_TIERMEDd8', 1.032812911402553),
#              ('DDP1_d6_VOLFRAC', 0.05214158437703798),
#              ('DDP1_d6_TIERMEDd8', 2.049219367103829),
#              ('DDP1_d7_VOLFRAC', 0.01311459480085179),
#              ('DDP1_d7_TIERMEDd8', 3.300181158736169),
#              ('DDP1_d8_VOLFRAC', 0.007748438047453653),
#              ('DDP1_d8_TIERMEDd8', 4.785698286299573),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
@np.vectorize
def fillfactor_expectation(bound_dist, radius=None, nbar=None):
    # https://en.wikipedia.org/wiki/Spherical_cap
    if radius == None:
        radius   = rand.meta['RSPHERE']
        V_sphere = rand.meta['VOL8']
        
    else:
        radius   = radius
        V_sphere = (4./3.) * np.pi * radius ** 3.

    if bound_dist > radius:
        h    = 0
        
    else:
        h    = np.abs(radius - bound_dist)
        
    a        = np.sqrt(2 * h * radius - h * h)
    
    V_cap    = (np.pi * h / 6.) * (3. * a * a + h * h)

    V_res    = V_sphere - V_cap
    
    fill_factor = V_res / V_sphere
    
    return fill_factor

# %%
@np.vectorize
def fillfactor_poisson(fill_factors, nbar=None, radius=None):
    if nbar == None:
        nbar = rand.meta['RAND_DENS']
    
    if radius == None:
        radius   = rand.meta['RSPHERE']
        V_sphere = rand.meta['VOL8']
        
    else:
        radius   = radius
        V_sphere = (4./3.) * np.pi * radius ** 3.
    
    NRAND8        = nbar * V_sphere * fill_factors
    SIGMA_NRAND8  = np.sqrt(NRAND8)
    SIGMA_FFACTOR = SIGMA_NRAND8 / NRAND8
    
    return  NRAND8, SIGMA_NRAND8, SIGMA_FFACTOR

# %%
df = 1.e-3
fs = np.arange(df, 1.0, df)

for nbar in np.logspace(-1., 1., 10):
    nrand8, sigma_nrand8, sigma_ffactor = fillfactor_poisson(fs, nbar=nbar, radius=None)
    
    s2n = (1. - fs) / sigma_ffactor
    
    pl.plot(fs, s2n, lw=0.5, label='{:.2f}'.format(nbar))

pl.axhline(5., c='k', lw=0.5)
pl.axvline(.8,  c='k', lw=0.5)
    
pl.xlim(-0.1,  1.)
pl.ylim( 0.0, 75.)

pl.xlabel('Fill factor')
pl.ylabel('S/N on $\Delta$Fill Factor')

pl.legend(frameon=False, ncol=5)

# %%
rads  = np.arange(0., 15., 1.e-3)
fills = fillfactor_expectation(rads)

# %%
pl.plot(rads, fills, lw=0.5)

rad_0p8 = rads[np.argmin(np.abs(fills - 0.8))]

pl.axhline(0.8,     c='k', lw=0.5)
pl.axvline(rad_0p8, c='k', lw=0.5)

pl.xlim(0.0,  8.)
pl.ylim(0.0,  1.1)

pl.xlabel('Boundary distance [$h^{-1}$Mpc]')

pl.title('Bound dist. for fillfactor of 0.8: {:.2f}'.format(rad_0p8))
# Out:
# Text(0.5, 1.0, 'Bound dist. for fillfactor of 0.8: 3.41')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['BOUND_DIST'][isin], rand['FILLFACTOR'][isin], marker='.', lw=0.0, s=1, alpha=0.1, c='k')

pl.plot(rads, fills, lw=0.8, c='c')

pl.xlabel('Boundary distance [$h^{-1}$Mpc]')
pl.ylabel(r'Random $N_8 \ / \ \langle N_8 \rangle$')

pl.axhline(1.00, c='k', lw=0.5)

pl.axvline(7.00, c='k', lw=0.5)
pl.axvline(8.00, c='k', lw=0.5)

pl.axvline(rad_0p8, c='k', lw=0.5)

pl.xlim(-0.1, 35.)
pl.ylim(0.0,  1.1)
# Out:
# (0.0, 1.1)

# %%
isin  = (~rand['IS_BOUNDARY'].astype(bool)) & (rand['BOUND_DIST'] > 7.) & (rand['BOUND_DIST'] <= 8.) & (rand['FILLFACTOR'] != 1.)
_     = pl.hist(rand['FILLFACTOR'][isin] - 1., color='k', histtype='step', bins=np.arange(-0.1, 0.1, 1.e-3))

#  sigma_nrand @ fillfactor = 1 
nrand8, sigma_nrand8 = fillfactor_poisson(fs)

sigma_fillfactor = sigma_nrand8[-1] / rand.meta['NRAND8']    
    
nrand  = np.count_nonzero(isin)

# HACK ??
nrand *= 2

draws  = norm.rvs(loc=0, scale=sigma_fillfactor, size=nrand) 
_      = pl.hist(draws, color='c', histtype='step', bins=np.arange(-0.1, 0.1, 1.e-3))

# %%
_ = pl.hist(rand['BOUND_DIST'], bins=50, histtype='step')
pl.xlabel('BOUND_DIST [$h^{-1}$Mpc]')
# Out:
# Text(0.5, 0, 'BOUND_DIST [$h^{-1}$Mpc]')

# %%
gold = Table.read(os.environ['HOME'] + '/data/{}/gama_gold_ddp_n8.fits'.format(version))
gold.meta
# Out:
# OrderedDict([('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('AREA', 180.0),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1ZLIMS_NGAL', 113687),
#              ('DDP1_NGAL', 45293),
#              ('DDP1_DENS', 0.005963721679858641),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2ZLIMS_NGAL', 73942),
#              ('DDP2_NGAL', 33396),
#              ('DDP2_DENS', 0.01057953807776663),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3ZLIMS_NGAL', 18121),
#              ('DDP3_NGAL', 8842),
#              ('DDP3_DENS', 0.01931329953669401),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('RPATH_0',
#               '/cosma/home/durham/dc-moor2/data/GAMA4/randoms//randoms_ddp1_bd_G9_0.fits'),
#              ('RPATH_1',
#               '/cosma/home/durham/dc-moor2/data/GAMA4/randoms//randoms_ddp1_bd_G12_0.fits'),
#              ('RPATH_2',
#               '/cosma/home/durham/dc-moor2/data/GAMA4/randoms//randoms_ddp1_bd_G15_0.fits'),
#              ('VOL8', 2144.660584850632),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
ddp_zmin  = gold.meta['DDP1_ZMIN']
ddp_zmax  = gold.meta['DDP1_ZMAX']

isin      = (rand['Z'] > ddp_zmin) & (rand['Z'] < ddp_zmax)

fills     = rand['FILLFACTOR'].data[isin]
pos_slice = pos[isin]

fills     = fills[np.abs(pos_slice[:,2]) < 5.]
pos_slice = pos_slice[np.abs(pos_slice[:,2]) < 5.]
    
plt.scatter(pos_slice[:,0],\
            pos_slice[:,1],\
            c=fills,\
            marker='.',\
            lw=0.0,\
            s=1,\
            vmin=0.,\
            vmax=1.,\
            cmap='hot')

pl.xlabel('$x$ [$h^{-1}$Mpc]')
pl.ylabel('$y$ [$h^{-1}$Mpc]')

pl.colorbar(label='FILLFACTOR')
    
plt.title('{}'.format(field))
plt.show()

# %%
for idx in np.arange(1, 4, 1):
    ddp_zmin  = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax  = gold.meta['DDP{}_ZMAX'.format(idx)]

    isin      = (rand['Z'] > ddp_zmin) & (rand['Z'] < ddp_zmax)

    fills     = rand['DDP{}_DELTA8'.format(idx)].data[isin]
    pos_slice = pos[isin]

    fills     = fills[np.abs(pos_slice[:,2]) < 5.]
    pos_slice = pos_slice[np.abs(pos_slice[:,2]) < 5.]
    
    plt.scatter(pos_slice[:,0],\
                pos_slice[:,1],\
                c=fills,\
                marker='.',\
                lw=0.0,\
                s=1,\
                vmin=0.,\
                vmax=1.,\
                cmap='hot')
    
    pl.xlabel('$x$ [$h^{-1}$Mpc]')
    pl.ylabel('$y$ [$h^{-1}$Mpc]')

    pl.xlim(100.,  800.)
    pl.ylim(-100., 100.)
    
    pl.colorbar(label='DDP{}  $\delta_8$'.format(idx))
    
    plt.title('{}:  DDP{}'.format(field, idx))
    plt.show()

# %%
cmap     = plt.cm.tab20c

cmaplist = [cmap(i) for i in range(cmap.N)]

cmap     = mpl.colors.LinearSegmentedColormap.from_list('Custom cmap', cmaplist, cmap.N)

bounds   = np.linspace(0, 9, 10)
norm     = mpl.colors.BoundaryNorm(bounds, cmap.N)

# %%
# np.unique(rand['DDP{}_DELTA8_TIER'.format(idx)])

# %%
#plt.scatter(rand['CARTESIAN_X'], rand['CARTESIAN_Y'], s='DDP1_'

# %%
for idx in np.arange(1, 2, 1):
    ddp_zmin  = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax  = gold.meta['DDP{}_ZMAX'.format(idx)]

    isin      = (rand['Z'] > ddp_zmin) & (rand['Z'] < ddp_zmax)
    isin      = rand['DDP{}_DELTA8_TIER'.format(idx)] > -999
    
    fills     = rand['DDP{}_DELTA8_TIER'.format(idx)].data[isin]
    pos_slice = pos[isin]

    fills     = fills[np.abs(pos_slice[:,2]) < 5.]
    pos_slice = pos_slice[np.abs(pos_slice[:,2]) < 5.]
    
    plt.scatter(pos_slice[:,0],\
                pos_slice[:,1],\
                c=fills,\
                marker='.',\
                lw=0.0,\
                s=1,\
                cmap=cmap,\
                norm=norm)
    
    pl.xlabel('$x$ [$h^{-1}$Mpc]')
    pl.ylabel('$y$ [$h^{-1}$Mpc]')

    pl.xlim(100.,  800.)
    pl.ylim(-100., 100.)
    
    pl.colorbar(label='DDP{}  $\delta_8$'.format(idx))
    
    plt.title('{}:  DDP{}'.format(field, idx))

# %%
# Larger minimum redshift & Smaller maximum redshift. 
isin = (rand['Z'] > gold.meta['DDP1_ZMIN']) & (rand['Z'] < gold.meta['DDP2_ZMAX'])

pl.plot(rand['DDP1_DELTA8'][isin], rand['DDP2_DELTA8'][isin], marker=',', lw=0.0, c='k')

pl.xlim(-1.2, 10.)
pl.ylim(-1.2, 10.)

pl.xlabel('DDP1 $\delta_8$')
pl.ylabel('DDP2 $\delta_8$')
# Out:
# Text(0, 0.5, 'DDP2 $\\delta_8$')

# %%
rand_ddp1fill = np.clip(np.sort(rand[rand['IN_DDP1']]['FILLFACTOR'].data)[::-1], 0, 1) 
rand_ddp2fill = np.clip(np.sort(rand[rand['IN_DDP2']]['FILLFACTOR'].data)[::-1], 0, 1)
rand_ddp3fill = np.clip(np.sort(rand[rand['IN_DDP3']]['FILLFACTOR'].data)[::-1], 0, 1)

# %%
plt.plot(rand_ddp1fill, np.cumsum(rand_ddp1fill) / len(rand_ddp1fill), lw=1, color='blue',  label=r'${:.3f} \leq z \leq {:.3f}$'.format(rand.meta['DDP1_ZMIN'], rand.meta['DDP1_ZMAX']))
plt.plot(rand_ddp2fill, np.cumsum(rand_ddp2fill) / len(rand_ddp2fill), lw=1, color='green', label=r'${:.3f} \leq z \leq {:.3f}$'.format(rand.meta['DDP2_ZMIN'], rand.meta['DDP2_ZMAX']))
plt.plot(rand_ddp3fill, np.cumsum(rand_ddp3fill) / len(rand_ddp3fill), lw=1, color='red',   label=r'${:.3f} \leq z \leq {:.3f}$'.format(rand.meta['DDP3_ZMIN'], rand.meta['DDP3_ZMAX']))

plt.xlabel('Fill factor')
plt.ylabel(r'Volume fraction ($\geq$ Fill factor)')

pl.xlim(0.0, 1.05)
pl.ylim(0.0, 1.05)

plt.legend(frameon=False, loc=3)

# %% [markdown]
# # Done.
