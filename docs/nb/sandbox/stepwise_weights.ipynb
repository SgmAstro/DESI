# %%
import os
import sys
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('/cosma/home/durham/dc-wils7/DESI/')

import pubplot

from   astropy.table import Table
from   findfile      import findfile
from   schechter     import named_schechter

# %%
os.environ['GOLD_DIR']    = '/cosma5/data/durham/dc-wils7/GAMA4/'
os.environ['RANDOMS_DIR'] = '/cosma5/data/durham/dc-wils7/GAMA4/randoms/'

# %%
survey = 'gama'

# %%
stepwise          = Table.read('/cosma5/data/durham/dc-wils7/GAMA4/gama_gold_lumfn_step.fits')
stepwise
# Out:
# <Table length=50>
#          Ms               PHI_STEP
#       float64             float64
# ------------------- -------------------
#               -25.5                 0.0
#               -25.3                 0.0
#               -25.1                 0.0
# -24.900000000000002                 0.0
# -24.700000000000003                 0.0
# -24.500000000000004                 0.0
# -24.300000000000004                 0.0
# -24.100000000000005                 0.0
# -23.900000000000006                 0.0
# -23.700000000000006                 0.0
#                 ...                 ...
#  -17.50000000000003 0.22042574795440317
#  -17.30000000000003  0.2610250656802713
#  -17.10000000000003  0.2494027466715096
#  -16.90000000000003 0.26465408772978116
#  -16.70000000000003  0.2968643630128096
# -16.500000000000032  0.2963109137852819
# -16.300000000000033  0.3582926964659477
# -16.100000000000033  0.3374111693862789
# -15.900000000000034 0.26001035292814545
# -15.700000000000035 0.16328914874473907

# %%
Ms = np.arange(-23., -15., 0.01)
sc = named_schechter(Ms, named_type='TMR')

pl.plot(Ms, np.log10(sc), label='TMR', lw=2)

pl.plot(stepwise['Ms'] , -1.1 + np.log10(stepwise['PHI_STEP']), label='STEPWISE', alpha=0.75, lw=2)

pl.xlabel(r'$M_r^e - 5 \log_{10}|h|$')
pl.ylabel(r'$\log_{10} \left[ \frac{\phi_\delta(M)}{h^{-3} \ {\rm Mpc}^{3} \ {\rm Mag}^{}} \right] $')

pl.ylim(-4.25, -1.25)
pl.xlim(-23., -15.5)

pl.legend(frameon=False, loc=2)
pl.title(survey.upper())
# Out:
# /tmp/ipykernel_130282/2913747496.py:6: RuntimeWarning: divide by zero encountered in log10
#   pl.plot(stepwise['Ms'] , -1.1 + np.log10(stepwise['PHI_STEP']), label='STEPWISE', alpha=0.75, lw=2)
# Text(0.5, 1.0, 'GAMA')

# %%
fpath  = findfile('ddp', version='v2')

ddp    = Table.read(fpath)
ddp
# Out:
# WARNING: DEFAULTING TO SURVEY = GAMA
# <Table length=113687>
#  CATAID       OBJID             RA          DEC      R_PETRO   ZGAMA    NQ  ... DELTA_DETMAG_BRIGHT          ZMIN         ZMIN_WARN DDP [3] DDPZLIMS [3]   DDPMALL_0P0_VISZ   WEIGHT_STEPWISE
#                                deg          deg        mag                  ...         mag
#  int32        int64          float64      float64    float32  float32 int16 ...       float32              float64         float64   int64     int64           float64            float64
#  544792 588848898855076298 216.87873507 -0.97925934 19.360544 0.25505     4 ...           -7.360544  0.008035729990385841       0.0  1 .. 0       1 .. 0 -19.949730224430372 10.589502667205135
#  561836 588848899377987791 185.05053157 -0.44348116 17.388186 0.08326     5 ...          -5.3881855  0.007506019781508557       0.0  0 .. 0       1 .. 1  -17.34044240492099 1.9898601062144676
#  300889 587726032227205452 131.22119797  1.08457648 17.518816 0.05123     5 ...           -5.518816  0.004227800457691613       0.0  0 .. 1       1 .. 1 -16.233574863485956 1.1794429707512417
#  486167 587729777983029443 218.75913077 -1.78088603 19.510452 0.24971     4 ...          -7.5104523  0.009636022254232556       0.0  1 .. 0       1 .. 0 -19.899645328510246  8.627247871084117
#  324184 587726032765649137 134.77713995  1.65159771 18.127356 0.12197     4 ...          -6.1273556  0.007481015389272087       0.0  0 .. 0       1 .. 0 -18.222720901439892 2.9154826542283168

# %%
pl.plot(ddp['ZGAMA'], 1. / ddp['WEIGHT_STEPWISE'], marker=',', lw=0.0)

pl.xlabel('$z$', fontsize=16)
pl.ylabel('Inverse stepwise weight $\equiv \overline n(z)$', fontsize=16)
# Out:
# Text(0, 0.5, 'Inverse stepwise weight $\\equiv \\overline n(z)$')

# %%
fpath = findfile('vmax')
vmax  = Table.read(fpath)
vmax
# Out:
# WARNING: DEFAULTING TO SURVEY = GAMA
# <Table length=113602>
#  ZGAMA          ZMIN                ZMAX             MCOLOR_0P0     FIELD   WEIGHT_STEPWISE   IN_D8LUMFN        VMAX                VZ
#                                                         mag
# float32       float64             float64             float64       bytes3      float64         int64         float64            float64
# ------- ------------------- ------------------- ------------------- ------ ------------------ ---------- ------------------ ------------------
# 0.16061 0.03903000056743622 0.22171711156749058 -19.346099537033727     G9  4.055363565159679          1  4663828.478649269 1825652.8704073972
# 0.20131 0.03903000056743622 0.24928139906578684 -20.073473681834898     G9  6.092189398390652          1  6522314.486863425  3530023.929602589
# 0.20351 0.03903000056743622 0.23207990684179042 -19.863761393912583    G12  6.092189398390652          1  5317091.689711269  3642811.837834562
#  0.1511 0.03903000056743622 0.15944518529453075 -18.915851506249098    G15  4.055363565159679          1 1786921.2870119934 1524566.1927770393
# 0.12415 0.03903000056743622 0.26298999786376953  -19.89991927366463    G12 2.9154826542283176          1  7594841.612883208  847350.4294453983
# 0.17617 0.03903000056743622 0.26298999786376953  -20.61170262619038     G9  4.584470153194735          0  7594841.612883208  2394699.185954092
#  0.0853 0.03903000056743622 0.26298999786376953 -19.665897414922096    G12 1.9898601062144676          1  7594841.612883208  262244.0920814757
# 0.17998 0.03903000056743622 0.26298999786376953 -20.437390656320304    G15  5.257448359247273          0  7594841.612883208  2549146.265940754
# 0.05233 0.03903000056743622 0.26298999786376953 -20.971485422742006     G9 1.1794429707512417          0  7594841.612883208  39848.51610339391
#     ...                 ...                 ...                 ...    ...                ...        ...                ...                ...
# 0.24969 0.03903000056743622 0.26298999786376953 -21.771606708471367    G12   8.62724787108412          0  7594841.612883208  6552823.905077065
# 0.09328 0.03903000056743622   0.215666978103653 -19.279372690977315    G12 2.1812023299140155          1  4306934.267614304  349942.0129192648
#  0.2506 0.03903000056743622 0.26298999786376953  -20.34210664390574    G12 10.589502667205137          0  7594841.612883208  6621092.188783866
# 0.25705 0.03903000056743622 0.26298999786376953 -20.980939457986203    G15 10.589502667205137          0  7594841.612883208 7117655.0439149905
# 0.17557 0.03903000056743622 0.17838668494243484  -18.87878794487607    G15  4.584470153194735          1 2483815.5715849344 2370930.0448125238
# 0.25947 0.03903000056743622 0.26298999786376953 -19.940077126322706    G12 10.589502667205137          0  7594841.612883208  7309744.883887114
# 0.12821 0.03903000056743622 0.14339418530397596 -18.659396831765893    G15 3.2372516172360464          1 1305210.3411683117  933733.7341855405
#  0.2619 0.03903000056743622 0.26298999786376953  -20.91579016589205    G15 10.589502667205137          0  7594841.612883208  7505836.404638463
# 0.14279 0.03903000056743622 0.22810772214332387  -19.86022019401497    G15  3.618347526917889          1  5060346.313859928   1288913.77975868
# 0.13966 0.03903000056743622 0.26298999786376953  -21.17219290047701    G15  3.618347526917889          0  7594841.612883208 1206544.1978162124

# %%
dM = 0.5
Ms = np.arange(-23., -17., dM)

dV = 0.025

for MM in Ms:
    isin = (vmax['MCOLOR_0P0'] > MM) & (vmax['MCOLOR_0P0'] < MM + dM)
    
    vv   = vmax[isin]    
    zmax = vv['ZMAX'].max()
    vlim = vv['VMAX'].max()
    
    nn   = vmax[vmax['ZGAMA'] < zmax]
    
    Mcnts, Mbins = np.histogram(vv['VZ'] / vv['VMAX'], bins=np.arange(-0.025, 1.025, dV))
    cnts,   bins = np.histogram(nn['VZ'] /       vlim, bins=np.arange(-0.025, 1.025, dV), weights=nn['WEIGHT_STEPWISE']) 

    pl.xlabel(r'$V/V_{\rm Max}$')
    pl.title(r'${:.3f} < $ MCOLOR_0P0 $ < {:.3f}$ to $z<{:.3f}$'.format(MM, MM+dM, zmax), fontsize=18)
    
    pl.axhline(dV, c='k', lw=0.5)
    
    toplot = [Mcnts, 1. * Mcnts / cnts]
    labels = ['Unweighted', 'Stepwise']
    
    for toplot, label in zip(toplot, labels):
        toplot  = np.array(toplot).astype(float)

        isin    = np.isfinite(toplot)
    
        toplot /= np.sum(toplot[isin])
    
        plt.step(Mbins[:-1][isin] + dV, toplot[isin], where='mid', lw=0.5, label=label)
    
    pl.legend(frameon=False, loc=4, fontsize=14)
    pl.show()
# Out:
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]
# /tmp/ipykernel_130282/1100081060.py:23: RuntimeWarning: invalid value encountered in true_divide
#   toplot = [Mcnts, 1. * Mcnts / cnts]

# %% [markdown]
# # Done.
