# %%
import os
import sys
import glob
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import numpy as np

from   mpl_toolkits.axes_grid1 import make_axes_locatable
from   astropy.table           import Table

# %%
#sys.path.append('/global/homes/m/mjwilson/desi/BGS/Sam/DESI/')

user = os.environ['USER']
sys.path.append('/cosma/home/durham/{}/DESI'.format(user))

# %%
from   gama_limits import gama_field
from   delta8_limits import delta8_tier

# %%
field = 'G9'

# %%
# Parameters
field = "G9"

# %%
#try:
#    gama_d8 = Table.read(os.environ['CSCRATCH'] + '/norberg/GAMA4/gama_gold_ddp_n8.fits')
#except:
#    gama_d8 = Table.read('/cosma/home/durham/{}/data/GAMA4/gama_gold_ddp_n8.fits'.format(user))   
 
gama_d8 = Table.read('/cosma/home/durham/{}/data/GAMA4/gama_gold_ddp_n8.fits'.format(user))
gama_d8
# Out:
# <Table length=113687>
#  CATAID       OBJID             RA          DEC      R_PETRO   ZGAMA  ... DDP2_N8 DDP3_N8     DDP1_DELTA8         DDP2_DELTA8         DDP3_DELTA8
#                                deg          deg        mag            ...
#  int32        int64          float64      float64    float32  float32 ...  int64   int64        float64             float64             float64
# ------- ------------------ ------------ ----------- --------- ------- ... ------- ------- ------------------- ------------------- -------------------
#  377217 587727943491322176 136.90329419  1.55608748 19.152271 0.16247 ...      73       0   9.599964863328967   8.990373079520078                -1.0
#  171040 587725040627351704 176.76489998 -2.36852638  16.70401 0.13018 ...      95       0   9.371925976977439   7.095483458730778                -1.0
#  219914 587726013994959291 179.46494151  1.59719091  19.49665 0.17699 ...      26       0  0.3069605292809181 0.15164744551087472                -1.0
#  560374 588848899375825181 180.05173692 -0.42679837 19.665287 0.22384 ...       0       0  0.6647563864419619                -1.0                -1.0
#   48006 587722982292455656 215.42459482  -0.7208216 18.141523 0.12539 ...      64       0   6.227695144904688   5.270808239668911                -1.0
#  513338 587729972326498715 223.37132101  -1.1056069 19.382643 0.17433 ...      11       0 0.24785254948978253 0.06331423305806227                -1.0
#  418433 587728879258632495 136.12480274   2.6338351 18.732468 0.20148 ...       0       0  10.011058247817425                -1.0                -1.0
# 3863293 588010930296521198 134.99147365 -1.88452248 19.798046 0.26287 ...       0       0                -1.0                -1.0                -1.0
#  559685 588848899374907541  177.9188338 -0.48488674 18.520073 0.16245 ...      67       0  2.7251949270092166  2.0759186155098845                -1.0
#   62434 587722982828212405 212.84279819 -0.25815029 19.346432 0.08231 ...      27      65  1.5056443150726233  1.4456575075911973   2.177465032816346
#   98071 587722984422703223 176.10963548  0.95790852 17.429028 0.17772 ...      31       0  0.6491979155406351 0.45909840085987796                -1.0
#     ...                ...          ...         ...       ...     ... ...     ...     ...                 ...                 ...                 ...
#  280114 587726031694594267 140.90463255  1.05787781  19.78012 0.19344 ...       0       0 0.26239063744500335                -1.0                -1.0
#  485439 587729777981653262 215.69845716  -1.9390027  18.77618  0.0913 ...       8      23  1.6015653392724158 0.12856983024853674  0.7510632553180534
#   39059 587722982274760818 174.96005287 -0.80295032 18.601995 0.05268 ...      14      20  1.0473641457560672  0.4129739507971406 0.08936060320387762
#  228219 587726014011211823 216.60727009  1.26770483  17.00036 0.05532 ...      97     204  11.529294656440234    9.46071858984919  10.872864235946672
# 3589784 587729150377459957 137.04913203 -1.80209068 14.304139 0.03987 ...      13      13  2.2934710146108244  1.3216722438756467  0.2529578427275805
#  342957 587726032802087112 218.13327132  2.23230827   18.9451 0.10957 ...      42       0  7.1730776698582215   4.640592011582187                -1.0
#  617712 588848900463984922 212.92127414  0.23622583 19.166676 0.23485 ...       0       0   2.290877730347351                -1.0                -1.0
#  139038 587724650333143239 185.43928959  -1.8123289  18.69333 0.25597 ...       0       0                -1.0                -1.0                -1.0
#   32444 587722981742215284 184.92549896 -1.06566937 19.750443 0.11885 ...      79       0   3.635366192070225  2.6103737434777083                -1.0
#   32235 587722981741822033 183.91770711 -1.23679484  18.21811 0.15752 ...      59       0  3.2468097417029433  1.9536613238723817                -1.0
# 3852926 588010930294161768 129.61311995 -1.78695091 18.920977  0.1878 ...       0       0    2.82993330358867                -1.0                -1.0

# %%
gama_d8['FIELD'] = gama_field(gama_d8['RA'], gama_d8['DEC'])

# %%
np.unique(gama_d8['FIELD'].data)
# Out:
# array(['G12', 'G15', 'G9'], dtype='<U4')

# %%
gama_d8 = gama_d8[gama_d8['FIELD'] == field]

# %%
# gama_d8 = gama_d8[gama_d8['FILLFACTOR'] > 0.8]

# %%
bins=np.arange(-1., 150., 1.)

_ = pl.hist(gama_d8['DDP1_N8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_N8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_N8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$N_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
bins=np.arange(-1., 10., 0.1)

_ = pl.hist(gama_d8['DDP1_DELTA8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_DELTA8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_DELTA8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$\delta_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 35))

for idx, ax in enumerate(axes):
    sc = ax.scatter(gama_d8['MCOLOR_0P0'], gama_d8['DDP1_DELTA8'], c=gama_d8['DDP1_N8'], marker='.', lw=0.0, s=12)

    ax.set_xlabel('MCOLOR_0P0')
    ax.set_ylabel('DDP1_DELTA8')

    ax.set_xlim(-23., -16.)
    ax.set_ylim(-1.1, 1.)
    
    ax.spines['top'].set_visible(False)
    
    divider = make_axes_locatable(ax)
    
    axLog = divider.append_axes("top", size=5.0, pad=0, sharex=ax)
    axLog.set_yscale('log')
    axLog.set_xlim((-16., -23.))
    axLog.set_ylim((1., 50.))
    axLog.scatter(gama_d8['MCOLOR_0P0'], gama_d8['DDP1_DELTA8'], c=gama_d8['DDP1_N8'], marker='.', lw=0.0, s=12)

    axLog.spines['bottom'].set_visible(False)
    axLog.xaxis.set_ticks_position('top')
    axLog.xaxis.set_visible(False)

    axLog.set_yticks([10.])
    axLog.set_yticklabels(['10'])
    
    ax.set_title('DDP{}'.format(idx+1))

    colorbar = fig.colorbar(sc, ax=ax, label=r'$N_8$')

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 30))

gama_d8_slice = gama_d8[np.abs(gama_d8['CARTESIAN_Z']) < 5.]

for idx in range(3):
    sc = axes[idx].scatter(gama_d8_slice['CARTESIAN_X'],\
                           gama_d8_slice['CARTESIAN_Y'],\
                           c=gama_d8_slice['DDP{}_DELTA8'.format(idx+1)],\
                           marker='.',\
                           lw=0.0,\
                           s=3,\
                           vmin=-1.,\
                           vmax=10.)
    
    # axes[idx].set_ylim(100., -100.)
    
    colorbar = fig.colorbar(sc, ax=axes[idx], label=r'$\delta_8$')    
    
    axes[idx].set_xlabel('x [Mpc/h]')
    axes[idx].set_ylabel('y [Mpc/h]')
    
    axes[idx].set_title('DDP{}'.format(idx+1))

# %%
tiers = delta8_tier(gama_d8['DDP1_DELTA8'])

# %%
np.unique(tiers, return_counts=True)
# Out:
# (array([-99,   0,   1,   2,   3]), array([13480,  3118,  1302,  3617, 12843]))

# %% [markdown]
# # Done.
