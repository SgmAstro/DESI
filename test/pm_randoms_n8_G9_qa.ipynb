# %%
import os
import sys
import fitsio
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib as mpl

from   astropy.table import Table
import pubplot

# %%
repo_root = os.environ['HOME'] + '/DESI/'

sys.path.append(repo_root)

# %%
from   cosmo         import cosmo, fsky

# %%
field  = 'G9'
dryrun = False
realz  = 0

# %%
# Parameters
field = "G9"

# %%
fpath = os.environ['HOME'] + '/data/GAMA4/randoms/randoms_{}_{}.fits'.format(field, realz)
rand  = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 1265955),
#              ('FIELD', 'G9'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763)])

# %%
fpath = os.environ['HOME'] + '/data/GAMA4/randoms/randoms_bd_{}_{}.fits'.format(field, realz)

if dryrun:
    fpath = fpath.replace('.fits', '_dryrun.fits')

rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 1265955),
#              ('FIELD', 'G9'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7773617545647357)])

# %%
rand
# Out:
# <Table length=1265955>
# RANDOM_RA  RANDOM_DEC      Z          V       RANDID ... RAND_N8      FILLFACTOR         BOUND_DIST     BOUND_ID
#  float32    float32     float32    float32    int64  ...  int32        float64            float64        int64
# --------- ----------- ----------- ---------- ------- ... ------- ------------------- ------------------ --------
# 138.82312   2.6346161  0.16503014   668692.4  758508 ...     770  0.7180623409028872 3.1038591445442103   442794
# 138.43556   1.4576548  0.20703317  1285581.6  853364 ...    1092  1.0183429561895492  15.73602943250421    41365
# 134.11272   2.7493808   0.1850888  931513.56  310374 ...     781   0.728320374344357  2.089423479684761   330221
# 137.29915  -1.4540813   0.1970547  1115599.2  289390 ...    1020  0.9511994645726558 5.2932219615818354   505132
# 133.44199   2.3860934   0.1633726   649419.3  799389 ...     958  0.8933814579025532  4.903895469738827   126298
# 134.45384  0.30523264  0.26233864  2523403.8  544760 ...     695  0.6481212038019567                0.0        0
#  131.9416  -1.4688603  0.23366278  1816753.1  355989 ...    1094  1.0202080531789073  5.993235767056326   978429
# 140.93097   2.2460127  0.19995879  1163496.5  359620 ...     620  0.5781800667010261                0.0        0
# 129.20674  -1.4824532  0.13962081  411389.75 1100812 ...     584  0.5446083208925794   1.44054027905796  1146971
# 131.56517  0.51997846  0.23105101  1759486.8   54503 ...    1142   1.064970380923503  28.10487628222826  1162357
# 135.91284  -0.7511063  0.18708472  960759.25 1159226 ...    1044  0.9735806284449536 11.583706472681714   412684
# 134.43272   1.8773314  0.13420278  366554.72  443959 ...    1076  1.0034221802746839  7.487263710547841   969875
#  132.3731  -1.2482489  0.21791454  1488690.8  938075 ...    1113  1.0379264745778098  7.948894807113028  1253754
#       ...         ...         ...        ...     ... ...     ...                 ...                ...      ...
# 133.46797 -0.09484445   0.1253794  300529.25  170678 ...    1043  0.9726480799502746 12.049315856257104   614916
# 129.46716  0.21854912  0.20366676  1226522.8  963884 ...     924  0.8616748090834647  3.727943561287424   471093
# 135.87039  0.20694701  0.26290342  2538794.2  750215 ...     528 0.49238560519055125                0.0        0
# 135.52066   2.8621624  0.20510854  1251601.1  394157 ...     734  0.6844905950944405 1.3894680688950156   908440
# 130.56656  -1.3391792  0.17316437  768588.44  497843 ...     963  0.8980442003759486  5.799232738254784   680641
# 139.27779  -1.5976005  0.14624305   470813.1  612564 ...     802  0.7479038927326176   3.05999619003763   935104
# 137.30214   2.3982742  0.16892704  715438.94  571204 ...    1000  0.9325484946790743   4.97031420587355   271241
# 135.94333   2.9296904  0.16873147   713044.5 1231344 ...     590  0.5502036118606538 1.2083599087671473   451500
# 137.83894   1.0696222 0.088608995 108471.805  603740 ...    1065  0.9931641468332142   8.68305440620013   878465
# 140.77179    1.425527  0.23150301  1769314.5  571956 ...     794  0.7404435047751851 2.4518447317048224   774980
#  139.1315   1.0318261  0.26223958  2520710.0  317332 ...     721  0.6723674646636126                0.0        0
# 133.73616 -0.84495234  0.14508624  460058.44  749411 ...    1041  0.9707829829609164  8.460534896897533  1232586
# 130.44984  -1.4581957  0.21520245  1436300.1  169639 ...    1041  0.9707829829609164  5.706660308266824   650975
# 136.62115 -0.13946685  0.25692454  2378805.5 1029015 ...    1067  0.9950292438225723 13.989774353521176   868769

# %%
fpath = os.environ['HOME'] + '/data/GAMA4/randoms/randoms_bd_ddp_n8_{}_{}.fits'.format(field, realz)

if dryrun:
    fpath = fpath.replace('.fits', '_dryrun.fits')

rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.039),
#              ('ZMAX', 0.263),
#              ('DZ', 0.0001),
#              ('NRAND', 1265955),
#              ('FIELD', 'G9'),
#              ('AREA', 180.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 2531908.950723488),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7773617545647357),
#              ('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1_NGAL', 45889),
#              ('DDP1_DENS', 0.006042196899455394),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2_NGAL', 32698),
#              ('DDP2_DENS', 0.01035841825568372),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3_NGAL', 8748),
#              ('DDP3_DENS', 0.01910797832470021),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('D8_LIMITS',
#               '[[-1.0, -0.75], [-0.4, 0.0], [0.7, 1.6], [4.0, 10000.0]]'),
#              ('DDP1_d-99_VOLFRAC', 0.4368696723836911),
#              ('DDP1_d-99_TIERMEDd8', 0.05415742942214563),
#              ('DDP1_d0_VOLFRAC', 0.2884737835852142),
#              ('DDP1_d0_TIERMEDd8', -0.9196588755246229),
#              ('DDP1_d1_VOLFRAC', 0.1629470457651622),
#              ('DDP1_d1_TIERMEDd8', -0.223397055383998),
#              ('DDP1_d2_VOLFRAC', 0.103391504254193),
#              ('DDP1_d2_TIERMEDd8', 1.05495254388787),
#              ('DDP1_d3_VOLFRAC', 0.008317994011739518),
#              ('DDP1_d3_TIERMEDd8', 4.839309551083357),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
pl.plot(rand['RANDOM_RA'][::10], rand['RANDOM_DEC'][::10], marker=',', lw=0.0, c='k')
pl.plot(rand['RANDOM_RA'][rand['IS_BOUNDARY'].astype(bool)], rand['RANDOM_DEC'][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='cyan')

# %%
_ = pl.hist(rand['V'], bins=100, histtype='step', color='k')
_ = pl.hist(rand['V'][rand['IS_BOUNDARY'].astype(bool)], bins=100, histtype='step', color='c')

# %%
_ = pl.hist(rand['Z'], bins=100, histtype='step', color='k')
pl.axvline(300. / 2.9979e5, lw=0.5, c='k')
pl.yscale('log')
pl.xlabel('Z')

pl.xlim(0.0, 0.6)
# Out:
# (0.0, 0.6)

# %%
pl.plot(rand['CARTESIAN_X'][::10], rand['CARTESIAN_Y'][::10], marker=',', lw=0.0, c='k')

# %%
pl.plot(rand['CARTESIAN_X'][rand['IS_BOUNDARY'].astype(bool)], rand['CARTESIAN_Y'][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='k')
pl.xlabel('x')
pl.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(rand['CARTESIAN_X'][::10],\
           rand['CARTESIAN_Y'][::10],\
           rand['CARTESIAN_Z'][::10],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(rand['CARTESIAN_X'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           rand['CARTESIAN_Y'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           rand['CARTESIAN_Z'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
np.mean(rand['V'] < np.percentile(rand['V'], 1.))
# Out:
# 0.010000355462871903

# %%
np.mean(rand['IS_BOUNDARY'].data)
# Out:
# 0.058793559012761114

# %%
rand.dtype.names
# Out:
# ('RANDOM_RA',
#  'RANDOM_DEC',
#  'Z',
#  'V',
#  'RANDID',
#  'FIELD',
#  'CARTESIAN_X',
#  'CARTESIAN_Y',
#  'CARTESIAN_Z',
#  'IS_BOUNDARY',
#  'RAND_N8',
#  'FILLFACTOR',
#  'BOUND_DIST',
#  'BOUND_ID',
#  'DDP1_N8',
#  'DDP2_N8',
#  'DDP3_N8',
#  'IN_DDP1',
#  'DDP1_DELTA8',
#  'DDP2_DELTA8',
#  'DDP3_DELTA8',
#  'DDP1_DELTA8_TIER')

# %%
rand['RAND_N8'].data.min(), rand['RAND_N8'].data.max()
# Out:
# (154, 1223)

# %%
_ = pl.hist(rand['RAND_N8'], bins=np.arange(0, 1500, 1), histtype='step')
pl.axvline(rand.meta['NRAND8'], c='k', lw=0.5)
pl.xlabel(r'$N_8$')
pl.xlim(50., 1500.)
# Out:
# (50.0, 1500.0)

# %%
# 100. * np.sqrt(rand.meta['NRAND8']) / rand.meta['NRAND8']

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['V'][isin], s=2)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='V')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_Y'][isin], rand['CARTESIAN_Z'][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('y')
pl.ylabel('z')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['RAND_N8'][isin], vmin=0, vmax=1500, s=2)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='N8')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['BOUND_DIST'][isin], rand['RAND_N8'][isin] / rand.meta['NRAND8'], marker='.', lw=0.0, s=1, alpha=0.1, c='k')

pl.xlabel('BOUNDARY DISTANCE [Mpc/h]')
pl.ylabel(r'Random $N_8 / <N_8>$')

pl.axhline(1.00, c='k', lw=0.5)
pl.axvline(8.00, c='k', lw=0.5)

pl.ylim(0.2, 1.2)
# Out:
# (0.2, 1.2)

# %%
_ = pl.hist(rand['BOUND_DIST'], bins=50, histtype='step')
pl.xlabel('BOUND_DIST [Mpc/h]')
# Out:
# Text(0.5, 0, 'BOUND_DIST [Mpc/h]')

# %%
gold = Table.read(os.environ['HOME'] + '/data/GAMA4/gama_gold_ddp_n8.fits')
gold.meta
# Out:
# OrderedDict([('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('AREA', 180.0),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1_NGAL', 45889),
#              ('DDP1_DENS', 0.006042196899455394),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2_NGAL', 32698),
#              ('DDP2_DENS', 0.01035841825568372),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3_NGAL', 8748),
#              ('DDP3_DENS', 0.01910797832470021),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('RPATH_0',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G9_0.fits'),
#              ('RPATH_1',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G12_0.fits'),
#              ('RPATH_2',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G15_0.fits'),
#              ('VOL8', 2144.660584850632),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

# TODO: Get from randoms header when available. 
ddp_zmin = gold.meta['DDP1_ZMIN']
ddp_zmax = gold.meta['DDP1_ZMAX']
        
isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
randoms_slice = randoms_slice_nolimits[isin]
    
plt.scatter(randoms_slice['CARTESIAN_X'],\
            randoms_slice['CARTESIAN_Y'],\
            c=randoms_slice['FILLFACTOR'],\
            marker='.',\
            lw=0.0,\
            s=1,\
            vmin=0.,\
            vmax=1.,\
            cmap='hot')

pl.xlabel('x [Mpc/h]')
pl.ylabel('y [Mpc/h]')

pl.colorbar(label='FILLFACTOR')
    
# pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
# pl.ylim(-80., 80.)
    
plt.title('{}'.format(field))
plt.show()

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

for idx in np.arange(1, 4, 1):
    # TODO: Get from randoms header when available. 
    ddp_zmin = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax = gold.meta['DDP{}_ZMAX'.format(idx)]
        
    isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
    randoms_slice = randoms_slice_nolimits[isin]
    
    plt.scatter(randoms_slice['CARTESIAN_X'],\
                randoms_slice['CARTESIAN_Y'],\
                c=randoms_slice['DDP{}_DELTA8'.format(idx)],\
                marker='.',\
                lw=0.0,\
                s=1,\
                vmin=-1.,\
                vmax=10.,\
                cmap='hot')

    pl.xlabel('x [Mpc/h]')
    pl.ylabel('y [Mpc/h]')

    pl.colorbar(label='DDP{}_DELTA8'.format(idx))
    
    # pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
    # pl.ylim(-80., 80.)
    
    plt.title('{}:  DDP{}'.format(field, idx))
    plt.show()

# %%
cmap = plt.cm.tab20c  # define the colormap

# extract all colors from the .jet map

cmaplist = [cmap(i) for i in range(cmap.N)]

# create the new map
cmap = mpl.colors.LinearSegmentedColormap.from_list('Custom cmap', cmaplist, cmap.N)

# define the bins and normalize
bounds = np.linspace(0, 4, 5)
norm   = mpl.colors.BoundaryNorm(bounds, cmap.N)

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

for idx in np.arange(1, 2, 1):
    # TODO: Get from randoms header when available. 
    ddp_zmin = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax = gold.meta['DDP{}_ZMAX'.format(idx)]
        
    isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
    randoms_slice = randoms_slice_nolimits[isin]
    
    plt.scatter(randoms_slice['CARTESIAN_X'],\
                randoms_slice['CARTESIAN_Y'],\
                c=randoms_slice['DDP{}_DELTA8_TIER'.format(idx)],\
                marker='.',\
                lw=0.0,\
                s=1,\
                cmap=cmap,\
                norm=norm)

    pl.xlabel('x [Mpc/h]')
    pl.ylabel('y [Mpc/h]')

    pl.colorbar(label='DDP{}_DELTA8_TIER'.format(idx))
    
    # pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
    # pl.ylim(-80., 80.)
    
    plt.title('{}:  DDP{}'.format(field, idx))
    plt.show()

# %%
# Larger minimum redshift. 
ddp1_zmin = gold.meta['DDP1_ZMIN']

# Smaller maximum redshift. 
ddp3_zmax = gold.meta['DDP2_ZMAX']
            
isin = (rand['Z'] > ddp1_zmin) & (rand['Z'] < ddp3_zmax)

pl.plot(rand['DDP1_DELTA8'][isin], rand['DDP2_DELTA8'][isin], marker=',', lw=0.0, c='k')

pl.xlabel('DDP1_DELTA8')
pl.ylabel('DDP2_DELTA8')
# Out:
# Text(0, 0.5, 'DDP2_DELTA8')

# %% [markdown]
# # Done.
