# %%
import os
import sys
import fitsio
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib as mpl

# %%
#repo_root = '/global/homes/m/{}/desi/BGS/Sam/DESI/'.format(os.environ['USER'])

repo_root = '/cosma/home/durham/{}/DESI'.format(os.environ['USER'])
sys.path.append(repo_root)

# %%
from   astropy.table import Table
from   cosmo         import cosmo, fsky

# %%
user = os.environ['USER']
field = 'G9'
realz = 0

# %%
# Parameters
field = "G15"

# %%
try:
    fpath = os.environ['CSCRATCH'] + '/desi/BGS/Sam/randoms_{}_{}.fits'.format(field, realz)
    
except:
    fpath = '/cosma/home/durham/{}/data/GAMA4/randoms/randoms_{}_{}.fits'.format(user, field, realz)    

rand  = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.0),
#              ('ZMAX', 0.3),
#              ('DZ', 0.0001),
#              ('NRAND', 1840387),
#              ('FIELD', 'G15'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 3680772.57902396),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763)])

# %%
try:
    fpath = os.environ['CSCRATCH'] + '/desi/BGS/Sam/randoms_bd_{}_{}.fits'.format(field, realz)
except:
    fpath = '/cosma/home/durham/{}/data/GAMA4/randoms/randoms_bd_{}_{}.fits'.format(user, field, realz)    
    
rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.0),
#              ('ZMAX', 0.3),
#              ('DZ', 0.0001),
#              ('NRAND', 1840387),
#              ('FIELD', 'G15'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 3680772.57902396),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7994894552069755)])

# %%
#os.environ['CSCRATCH'] + '/desi/BGS/Sam/'

# %%
#! ls '/global/cscratch1/sd/mjwilson/desi/BGS/Sam/'

# %%
rand
# Out:
# <Table length=1840387>
# RANDOM_RA  RANDOM_DEC      Z          V      RANDID FIELD  CARTESIAN_X CARTESIAN_Y CARTESIAN_Z IS_BOUNDARY   N8       FILLFACTOR         BOUND_DIST     BOUND_ID
#  float32    float32     float32    float32   int64  bytes3   float32     float32     float32      int64    int32       float64            float64        int64
# --------- ----------- ----------- --------- ------- ------ ----------- ----------- ----------- ----------- ----- ------------------- ------------------ --------
#  216.6185   -0.808964  0.16447665  662216.5  541755    G15    477.0616  -7.3086348  -10.883285           0  1090   1.016477859200191  9.774657518542892   673717
# 221.45676   2.6404722  0.24579756 2098134.0 1104169    G15    698.7809   48.364056    26.22122           0   970  0.9045720398387022  4.346966069687991   337314
#  212.5458  -0.3668098  0.24854927 2165501.2 1081817    G15   705.64355   -61.12442  -10.666243           0  1065  0.9931641468332142 11.795548078978328   424942
# 216.16829  0.29416147  0.23967364 1952958.9  827053    G15    684.2005 -15.8584385  -2.4309745           0  1102    1.02766844113634  26.83388185444483  1111677
# 214.81216  -1.2098874  0.29574084 3536238.2  327255    G15   832.88025   -39.05185   -24.85066           0  1122  1.0463194110299214  8.758971243012246   131328
# 222.82349  0.18291417  0.22972178 1730783.0  440858    G15    654.5348   61.035774   -3.588301           0  1071  0.9987594378012886  6.886263252732602   128403
#  216.6087   1.6039363   0.2313871 1766791.0 1517314    G15    661.7091  -10.246899   12.778438           0  1086  1.0127476652214746 15.762103957063424   733501
# 212.42409  -1.4552088  0.25887063 2430169.2  750039    G15   732.81445  -65.057556  -25.062084           0  1091    1.01741040769487  6.903613305774649  1209507
#  220.9361  -1.5180924 0.122164436 278546.25 1448881    G15   356.71265   21.448433  -12.572896           0   803  0.7488364412272966 3.4296305560822598   458530
# 218.82803 -0.70231545   0.2782673 2980082.8  209898    G15    787.5326    18.31389  -16.500824           0  1050  0.9791759194130281 17.334764096823434   583782
# 213.55151  -1.5848706 0.049768776  19666.61  608181    G15   147.34338  -10.162839    -5.36793           1   557  0.5194295115362444                0.0        0
# 221.09767    2.411619  0.24593917 2101568.8  611497    G15    699.5504   44.017124     23.4335           0  1099  1.0248707956523027  7.000764620277871   233614
#  223.0259 -0.56877154   0.2934116 3458697.5  108526    G15    824.0268    79.78753  -15.379619           0  1083  1.0099500197374376   5.20012732906235   556792
# 220.51611 -0.33003342  0.27769208 2962766.5  966869    G15     785.215   41.430367  -11.352366           0  1045  0.9745131769396327  22.37837670247753   476178
#   217.031 -0.20420909  0.21290883 1392915.0 1664694    G15    611.4107  -4.9632716   -7.491809           0  1067  0.9950292438225723 18.730850186684204    62530
# 223.07492   2.7773197  0.09959532 153014.45 1405099    G15    291.2355   28.436356   11.660081           0   473 0.44109543798320217 1.3938775323537667   183216
# 217.94148  -1.9440484  0.28426534 3164386.0 1395810    G15   803.08325   6.2453012  -34.247772           0   591   0.551136160355333 1.1339015600798168  1136657

# %%
try:
    fpath = os.environ['CSCRATCH'] + '/desi/BGS/Sam/randoms_bd_ddp_n8_{}_{}.fits'.format(field, realz)
except:
    fpath = '/cosma/home/durham/{}/data/GAMA4/randoms/randoms_bd_ddp_n8_{}_{}.fits'.format(user, field, realz)    

rand = Table.read(fpath)
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.0),
#              ('ZMAX', 0.3),
#              ('DZ', 0.0001),
#              ('NRAND', 1840387),
#              ('FIELD', 'G15'),
#              ('AREA', 180.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 3680772.57902396),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.330292425316),
#              ('NRAND8_PERR', 32.74645465428763),
#              ('RSPHERE', 8.0),
#              ('FILLFACTOR_INFRAC', 0.7994894552069755),
#              ('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2483299970626831),
#              ('DDP1_VZ', 6451530.309761721),
#              ('DDP1_NGAL', 34732),
#              ('DDP1_DENS', 0.005383528919866887),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1830800026655197),
#              ('DDP2_VZ', 2679079.755786839),
#              ('DDP2_NGAL', 26598),
#              ('DDP2_DENS', 0.009928035902084681),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.09973999857902527),
#              ('DDP3_VZ', 432372.2344703938),
#              ('DDP3_NGAL', 7954),
#              ('DDP3_DENS', 0.01839618589233126),
#              ('D8_LIMITS',
#               '[[-1.0, -0.75], [-0.4, 0.0], [0.7, 1.6], [4.0, 10000.0]]'),
#              ('DDP1_d-99_VOLFRAC', 0.4380707982874772),
#              ('DDP1_d-99_TIERMEDd8', 0.001602655619880045),
#              ('DDP1_d0_VOLFRAC', 0.3007769227978894),
#              ('DDP1_d0_TIERMEDd8', -0.9154905526733165),
#              ('DDP1_d1_VOLFRAC', 0.1547111582781389),
#              ('DDP1_d1_TIERMEDd8', -0.224187138085708),
#              ('DDP1_d2_VOLFRAC', 0.09317957957064156),
#              ('DDP1_d2_TIERMEDd8', 1.065904545528608),
#              ('DDP1_d3_VOLFRAC', 0.01326154106585288),
#              ('DDP1_d3_TIERMEDd8', 4.887118386949566),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
pl.plot(rand['RANDOM_RA'][::10], rand['RANDOM_DEC'][::10], marker=',', lw=0.0, c='k')
pl.plot(rand['RANDOM_RA'][rand['IS_BOUNDARY'].astype(bool)], rand['RANDOM_DEC'][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='cyan')

pl.xlim(122.5, 142.5)
pl.ylim(-3., 4.)
# Out:
# (-3.0, 4.0)

# %%
_ = pl.hist(rand['V'], bins=100, histtype='step', color='k')
_ = pl.hist(rand['V'][rand['IS_BOUNDARY'].astype(bool)], bins=100, histtype='step', color='c')

# %%
_ = pl.hist(rand['Z'], bins=100, histtype='step', color='k')
pl.axvline(300. / 2.9979e5, lw=0.5, c='k')
pl.yscale('log')
pl.xlabel('Z')

pl.xlim(0.0, 0.6)
# Out:
# (0.0, 0.6)

# %%
pl.plot(rand['CARTESIAN_X'][::10], rand['CARTESIAN_Y'][::10], marker=',', lw=0.0, c='k')

# %%
pl.plot(rand['CARTESIAN_X'][rand['IS_BOUNDARY'].astype(bool)], rand['CARTESIAN_Y'][rand['IS_BOUNDARY'].astype(bool)], marker=',', lw=0.0, c='k')
pl.xlabel('x')
pl.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(rand['CARTESIAN_X'][::10],\
           rand['CARTESIAN_Y'][::10],\
           rand['CARTESIAN_Z'][::10],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(projection='3d')

ax.scatter(rand['CARTESIAN_X'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           rand['CARTESIAN_Y'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           rand['CARTESIAN_Z'][rand['IS_BOUNDARY'].astype(bool)][::10],\
           marker='.',\
           lw=0.0)

ax.set_xlim(0.0, 1000.)
# Out:
# (0.0, 1000.0)

# %%
np.mean(rand['V'] < np.percentile(rand['V'], 1.))
# Out:
# 0.010000070637317043

# %%
np.mean(rand['IS_BOUNDARY'].data)
# Out:
# 0.058758293771907756

# %%
rand['N8'].data.min(), rand['N8'].data.max()
# Out:
# (12, 1227)

# %%
_ = pl.hist(rand['N8'], bins=np.arange(0, 1500, 1), histtype='step')
pl.axvline(rand.meta['NRAND8'], c='k', lw=0.5)
pl.xlabel('N8')
pl.xlim(50., 1500.)
# Out:
# (50.0, 1500.0)

# %%
# 100. * np.sqrt(rand.meta['NRAND8']) / rand.meta['NRAND8']

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['V'][isin], s=2)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='V')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_Y'][isin], rand['CARTESIAN_Z'][isin], lw=0.0, c=rand['BOUND_DIST'][isin], s=2, vmin=0., vmax=70.)
pl.xlabel('y')
pl.ylabel('z')
pl.colorbar(label='BOUNDARY DISTANCE')

# %%
isin = rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['CARTESIAN_X'][isin], rand['CARTESIAN_Y'][isin], lw=0.0, c=rand['N8'][isin], vmin=0, vmax=1500, s=2)
pl.xlabel('x')
pl.ylabel('y')
pl.colorbar(label='N8')

# %%
isin = ~rand['IS_BOUNDARY'].astype(bool)

pl.scatter(rand['BOUND_DIST'][isin], rand['N8'][isin] / rand.meta['NRAND8'], marker='.', lw=0.0, s=1, alpha=0.1, c='k')

pl.xlabel('BOUNDARY DISTANCE [Mpc/h]')
pl.ylabel(r'Random $N_8 / <N_8>$')

pl.axhline(1.00, c='k', lw=0.5)
pl.axvline(8.00, c='k', lw=0.5)

pl.ylim(0.2, 1.2)
# Out:
# (0.2, 1.2)

# %%
_ = pl.hist(rand['BOUND_DIST'], bins=50, histtype='step')
pl.xlabel('BOUND_DIST [Mpc/h]')
# Out:
# Text(0.5, 0, 'BOUND_DIST [Mpc/h]')

# %%
rand
# Out:
# <Table length=1840387>
# RANDOM_RA  RANDOM_DEC      Z          V      RANDID FIELD  ...      FILLFACTOR         DDP1_DELTA8          DDP2_DELTA8          DDP3_DELTA8     DDP1_DELTA8_TIER
#  float32    float32     float32    float32   int64  bytes3 ...       float64             float64              float64              float64            int64
# --------- ----------- ----------- --------- ------- ------ ... ------------------- -------------------- -------------------- ------------------- ----------------
#  216.6185   -0.808964  0.16447665  662216.5  541755    G15 ...  1.0164778592052301   2.3230820383954414   1.6336315912400963                -1.0              -99
# 221.45676   2.6404722  0.24579756 2098134.0 1104169    G15 ...  0.9045720398431865  -0.7127550022322735                 -1.0                -1.0              -99
#  212.5458  -0.3668098  0.24854927 2165501.2 1081817    G15 ...  0.9931641468381377  -0.9127925984867935                 -1.0                -1.0                0
# 216.16829  0.29416147  0.23967364 1952958.9  827053    G15 ...  1.0276684411414345 -0.49432368814030003                 -1.0                -1.0              -99
# 218.37224  -1.7450509  0.28237346 3105515.2 1542999    G15 ...  0.7898685749970916                 -1.0                 -1.0                -1.0              -99
# 215.67665   2.6008437  0.17796256  831746.6  575370    G15 ...  0.8448889361834299  -0.5899519531498238 -0.16618495571868674                -1.0              -99
# 217.71371   1.9626317   0.2526735 2268975.8 1759399    G15 ...  0.9978268893115562                 -1.0                 -1.0                -1.0              -99
# 221.20532 0.047041986  0.29556105 3530214.8  161017    G15 ...  1.0211406016786486                 -1.0                 -1.0                -1.0              -99
# 218.10945     2.12468  0.23722042 1896622.0 1646351    G15 ...  1.0034221802796583   3.1431620495865387                 -1.0                -1.0              -99
# 218.51154  -0.2078697  0.21278904 1390672.1 1501608    G15 ...   1.035128829098904  -0.7489841010498246                 -1.0                -1.0              -99
#  219.4013   0.8256367   0.2972364 3586585.5 1458249    G15 ...  0.9633225950082593                 -1.0                 -1.0                -1.0              -99
# 212.67052 -0.29181242  0.29678807 3571445.8  776054    G15 ...  1.0332637321095366                 -1.0                 -1.0                -1.0              -99
# 223.19331  0.73412955  0.29761732 3599478.0  170275    G15 ...  0.8458214846781135                 -1.0                 -1.0                -1.0              -99
# 216.57857   -1.456881  0.29385936 3473520.8 1013321    G15 ...  1.0034221802796583                 -1.0                 -1.0                -1.0              -99
# 218.89232  -1.5051764   0.2691632 2713299.5  255344    G15 ...   1.065902929423466                 -1.0                 -1.0                -1.0              -99
# 222.00636    0.667428  0.29612586 3549157.8  646718    G15 ...  0.9857037588806681                 -1.0                 -1.0                -1.0              -99
#  223.0259 -0.56877154   0.2934116 3458697.5  108526    G15 ...  1.0099500197424442                 -1.0                 -1.0                -1.0              -99
# 220.51611 -0.33003342  0.27769208 2962766.5  966869    G15 ...  0.9745131769444637                 -1.0                 -1.0                -1.0              -99
#   217.031 -0.20420909  0.21290883 1392915.0 1664694    G15 ...  0.9950292438275051                 -1.0                 -1.0                -1.0              -99
# 223.07492   2.7773197  0.09959532 153014.45 1405099    G15 ... 0.44109543798538886 -0.21458027389797119   -0.467627603862671                -1.0                1
# 217.94148  -1.9440484  0.28426534 3164386.0 1395810    G15 ...  0.5511361603580651                 -1.0                 -1.0                -1.0              -99

# %%
rand.meta
# Out:
# OrderedDict([('ZMIN', 0.0),
#              ('ZMAX', 0.3),
#              ('DZ', 0.0001),
#              ('NRAND', 1840387),
#              ('FIELD', 'G15'),
#              ('AREA', 60.0),
#              ('BOUND_PERCENT', 1.0),
#              ('VOL', 3680772.579023961),
#              ('RAND_DENS', 0.5),
#              ('VOL8', 2144.660584850632),
#              ('NRAND8', 1072.33029242),
#              ('NRAND8_PERR', 32.74645465428763)])

# %%
try:
    gold = Table.read(os.environ['CSCRATCH'] + '/norberg/GAMA4/gama_gold_ddp_n8.fits')
except:
    gold = Table.read('/cosma/home/durham/{}/data/GAMA4/gama_gold_ddp_n8.fits'.format(user))   

gold.meta
# Out:
# OrderedDict([('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2483299970626831),
#              ('DDP1_VZ', 6451530.309761727),
#              ('DDP1_NGAL', 34732),
#              ('DDP1_DENS', 0.005383528919866882),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1830800026655197),
#              ('DDP2_VZ', 2679079.755786841),
#              ('DDP2_NGAL', 26598),
#              ('DDP2_DENS', 0.009928035902084674),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.09973999857902527),
#              ('DDP3_VZ', 432372.2344703941),
#              ('DDP3_NGAL', 7954),
#              ('DDP3_DENS', 0.01839618589233124),
#              ('VOL8', 2144.660584850632)])

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

# TODO: Get from randoms header when available. 
ddp_zmin = gold.meta['DDP1_ZMIN']
ddp_zmax = gold.meta['DDP1_ZMAX']
        
isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
randoms_slice = randoms_slice_nolimits[isin]
    
plt.scatter(randoms_slice['CARTESIAN_X'],\
            randoms_slice['CARTESIAN_Y'],\
            c=randoms_slice['FILLFACTOR'],\
            marker='.',\
            lw=0.0,\
            s=1,\
            vmin=0.,\
            vmax=1.,\
            cmap='hot')

pl.xlabel('x [Mpc/h]')
pl.ylabel('y [Mpc/h]')

pl.colorbar(label='FILLFACTOR')
    
# pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
# pl.ylim(-80., 80.)
    
plt.title('{}'.format(field))
plt.show()

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

for idx in np.arange(1, 4, 1):
    # TODO: Get from randoms header when available. 
    ddp_zmin = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax = gold.meta['DDP{}_ZMAX'.format(idx)]
        
    isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
    randoms_slice = randoms_slice_nolimits[isin]
    
    plt.scatter(randoms_slice['CARTESIAN_X'],\
                randoms_slice['CARTESIAN_Y'],\
                c=randoms_slice['DDP{}_DELTA8'.format(idx)],\
                marker='.',\
                lw=0.0,\
                s=1,\
                vmin=-1.,\
                vmax=10.,\
                cmap='hot')

    pl.xlabel('x [Mpc/h]')
    pl.ylabel('y [Mpc/h]')

    pl.colorbar(label='DDP{}_DELTA8'.format(idx))
    
    pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
    pl.ylim(-80., 80.)
    
    plt.title('{}:  DDP{}'.format(field, idx))
    plt.show()

# %%
cmap = plt.cm.tab20c  # define the colormap

# extract all colors from the .jet map

cmaplist = [cmap(i) for i in range(cmap.N)]

# create the new map
cmap = mpl.colors.LinearSegmentedColormap.from_list('Custom cmap', cmaplist, cmap.N)

# define the bins and normalize
bounds = np.linspace(0, 4, 5)
norm   = mpl.colors.BoundaryNorm(bounds, cmap.N)

# %%
randoms_slice_nolimits = rand[np.abs(rand['CARTESIAN_Z']) < 5.]

for idx in np.arange(1, 2, 1):
    # TODO: Get from randoms header when available. 
    ddp_zmin = gold.meta['DDP{}_ZMIN'.format(idx)]
    ddp_zmax = gold.meta['DDP{}_ZMAX'.format(idx)]
        
    isin = (randoms_slice_nolimits['Z'] > ddp_zmin) & (randoms_slice_nolimits['Z'] < ddp_zmax)
    
    randoms_slice = randoms_slice_nolimits[isin]
    
    plt.scatter(randoms_slice['CARTESIAN_X'],\
                randoms_slice['CARTESIAN_Y'],\
                c=randoms_slice['DDP{}_DELTA8_TIER'.format(idx)],\
                marker='.',\
                lw=0.0,\
                s=1,\
                vmin=0.,\
                vmax=4.,\
                cmap=cmap,\
                norm=norm)

    pl.xlabel('x [Mpc/h]')
    pl.ylabel('y [Mpc/h]')

    pl.colorbar(label='DDP{}_DELTA8_TIER'.format(idx))
    
    pl.xlim(0, 1.1 * cosmo.comoving_distance(gold.meta['DDP1_ZMAX']).value)
    pl.ylim(-80., 80.)
    
    plt.title('{}:  DDP{}'.format(field, idx))
    plt.show()

# %%
# Larger minimum redshift. 
ddp1_zmin = gold.meta['DDP1_ZMIN']

# Smaller maximum redshift. 
ddp3_zmax = gold.meta['DDP2_ZMAX']
            
isin = (rand['Z'] > ddp1_zmin) & (rand['Z'] < ddp3_zmax)

pl.plot(rand['DDP1_DELTA8'][isin], rand['DDP2_DELTA8'][isin], marker=',', lw=0.0, c='k')

pl.xlabel('DDP1_DELTA8')
pl.ylabel('DDP2_DELTA8')
# Out:
# Text(0, 0.5, 'DDP2_DELTA8')

# %% [markdown]
# # Done.
