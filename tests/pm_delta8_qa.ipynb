# %%
import os
import sys
import glob
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import numpy as np

from   mpl_toolkits.axes_grid1 import make_axes_locatable
from   astropy.table           import Table, vstack

# %%
os.environ['CODE_ROOT'] = os.environ['HOME'] + '/DESI/'

sys.path.append(os.environ['CODE_ROOT'])

# %%
from   gama_limits import gama_field
from   delta8_limits import delta8_tier
import pubplot

# %%
field = 'G9'

# %%
gama_d8 = Table.read(os.environ['HOME'] + '/data/GAMA4/gama_gold_ddp_n8.fits')
gama_d8
# Out:
# <Table length=113687>
# CATAID       OBJID             RA          DEC     ...     DDP1_DELTA8           DDP2_DELTA8         DDP3_DELTA8
#                               deg          deg     ...
# int32        int64          float64      float64   ...       float64               float64             float64
# ------ ------------------ ------------ ----------- ... -------------------- --------------------- ------------------
#  32174 587722981741691177 183.70037809 -1.05288215 ...   0.6356962089955482   0.30107595736367454 0.7632803324051429
# 144355 587724650867524042 179.66102327 -1.40728884 ...   0.9280372369440453                  -1.0               -1.0
# 124541 587724649256976626 179.89751219 -2.57730755 ...  0.15223410165319318   0.09982091687020489               -1.0
# 118797 587724648722006137 184.17555062 -2.99648752 ...    4.516757213975895     4.305342340738256               -1.0
#  39636 587722982275940549 177.66111022 -0.65931048 ...  0.07970085268866534    0.4845361552659335               -1.0
# 341716 587726032799858903 212.96405368  2.36821727 ...   0.6790130651230986                  -1.0               -1.0
# 346622 587726033302389048 134.55743422  2.16600461 ... -0.32516731327511983   -0.2127230496523168               -1.0
# 177971 587725041165008988 178.47535786  -1.9391443 ...    3.149093169285493    2.8992412883776533               -1.0
# 172285 587725040629710998 182.12852956 -2.33236242 ...  -0.3349489007262123 -0.057877604696590534               -1.0
# 610500 588848900449698117 180.40976089   0.3388614 ...   0.8353724578801194      0.86190619163712               -1.0
# 302610 587726032230416728 138.53122634  1.38977696 ...   0.9513420713189848     0.517656811052335               -1.0
#  15080 588848901001314625 213.98366937  0.75510347 ... -0.34583906553645505   -0.2845367882679003               -1.0
# 208860 587725074988269832 130.61922805  0.12372122 ...    3.039177684825906      2.80601356088375 2.8317251258428056
#    ...                ...          ...         ... ...                  ...                   ...                ...
# 239465 587726014548607197 217.84292864  1.61146352 ...    5.889705841888448     4.504081149585731               -1.0
# 397461 587728307495960746 178.23268965  1.46131379 ...   0.6583438518965616                  -1.0               -1.0
# 568259 588848899390833081 214.28595511 -0.56610649 ...   2.5389570844886316    1.9866737263303715               -1.0
# 504301 587729971249021149 214.85375081 -1.96182197 ...   0.7899628231702156                  -1.0               -1.0
# 221119 587726013997187542  184.5819763  1.54322764 ...   1.6583337870453798                  -1.0               -1.0
# 249871 587726015083511922 213.27406905  2.13655058 ...   2.0589023462706812    2.1929517755224497               -1.0
# 138605 587724650332225697 183.35394211 -1.66570048 ...  -0.1836188876179169                  -1.0               -1.0
# 388293 587727944566178064  139.3411875  2.45004368 ...   1.1601760175206821    1.0354784706466647               -1.0
# 347688 587726033304224123 138.72775853  2.35475845 ...   2.7331439793821843                  -1.0               -1.0
# 129854 587724649791619154 174.84665374 -2.09774838 ...    4.329748494858069    3.4724669802166908               -1.0
# 497139 587729779055460959 215.79068217 -1.08132634 ...    0.999568135177137                  -1.0               -1.0
# 609348 588848900447469698 175.20879494  0.37359708 ...   0.5567087187951785                  -1.0               -1.0
#  40370 587722982277316680  180.8511958 -0.64678756 ...    0.953525925628858    1.0511296608297025               -1.0

# %%
gama_d8['ZGAMA'].min(), gama_d8['ZGAMA'].max()
# Out:
# (0.03903, 0.26299)

# %%
np.unique(gama_d8['FIELD'].data)
# Out:
# array([b'G12', b'G15', b'G9'], dtype='|S4')

# %%
gama_d8 = gama_d8[gama_d8['FIELD'] == field]

# %%
bins=np.arange(-1., 150., 1.)

_ = pl.hist(gama_d8['DDP1_N8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_N8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_N8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$N_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
bins=np.arange(-1., 10., 0.1)

_ = pl.hist(gama_d8['DDP1_DELTA8'], histtype='step', bins=bins, label='DDP1')
_ = pl.hist(gama_d8['DDP2_DELTA8'], histtype='step', bins=bins, label='DDP2')
_ = pl.hist(gama_d8['DDP3_DELTA8'], histtype='step', bins=bins, label='DDP3')

pl.xlabel(r'$\delta_8$')
pl.yscale('log')
pl.legend(frameon=False)

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 35))

for idx, ax in enumerate(axes):
    sc = ax.scatter(gama_d8['MCOLOR_0P0'],\
                    gama_d8['DDP1_DELTA8'],\
                    c=gama_d8['DDP1_N8'],\
                    marker='.',\
                    lw=0.0,\
                    s=12)

    ax.set_xlabel(r'$^{0.0}M_{\rm COLOUR}$', fontsize=16)
    ax.set_ylabel(r'$\delta_{8,DDP1}$', fontsize=16)

    ax.set_xlim(-23., -16.)
    ax.set_ylim(-1.1, 1.)
    
    ax.spines['top'].set_visible(False)
    
    divider = make_axes_locatable(ax)
    
    axLog = divider.append_axes("top", size=5.0, pad=0, sharex=ax)
    axLog.set_yscale('log')
    axLog.set_xlim((-16., -23.))
    axLog.set_ylim((1., 50.))
    axLog.scatter(gama_d8['MCOLOR_0P0'], gama_d8['DDP1_DELTA8'], c=gama_d8['DDP1_N8'], marker='.', lw=0.0, s=12)

    axLog.spines['bottom'].set_visible(False)
    axLog.xaxis.set_ticks_position('top')
    axLog.xaxis.set_visible(False)

    axLog.set_yticks([10.])
    axLog.set_yticklabels(['10'])
    
    ax.set_title('DDP{}'.format(idx+1))

    colorbar = fig.colorbar(sc, ax=ax, label=r'$N_8$')

# %%
realz  = 0
rpaths = [os.environ['HOME'] + '/data/GAMA4/randoms/randoms_bd_ddp_n8_G{}_{:d}.fits'.format(ff, realz) for ff in [9, 12, 15]]

print('Reading: {}'.format(rpaths))

rand   = None

for rpath in rpaths:
    if not os.path.isfile(rpath):
        raise  RuntimeError('Expect random bound dist. file for {}; Run bound_dist.py for this field'.format(rpath))

    if rand == None:
        rand = Table.read(rpath)

    else:
        rand = vstack([rand, Table.read(rpath)])
# Out:
# Reading: ['/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_bd_ddp_n8_G9_0.fits', '/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_bd_ddp_n8_G12_0.fits', '/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_bd_ddp_n8_G15_0.fits']
# /cosma/home/durham/dc-moor2/.local/lib/python3.9/site-packages/astropy/table/table.py:3488: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   result = self.as_array() == other
# WARNING: MergeConflictWarning: Cannot merge meta key 'FIELD' types <class 'str'> and <class 'str'>, choosing FIELD='G12' [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'FILLFACTOR_INFRAC' types <class 'float'> and <class 'float'>, choosing FILLFACTOR_INFRAC=0.7773585948947632 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d-99_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d-99_VOLFRAC=0.4566451521160363 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d-99_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d-99_TIERMEDd8=0.08008800876034106 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d0_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d0_VOLFRAC=0.2577701234782471 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d0_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d0_TIERMEDd8=-0.9190299821823499 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d1_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d1_VOLFRAC=0.1651377378911527 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d1_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d1_TIERMEDd8=-0.2244483766669314 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d2_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d2_VOLFRAC=0.1068683293701266 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d2_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d2_TIERMEDd8=1.068783955240961 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d3_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d3_VOLFRAC=0.01357865714443716 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d3_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d3_TIERMEDd8=4.73859407334928 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'FIELD' types <class 'str'> and <class 'str'>, choosing FIELD='G15' [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'FILLFACTOR_INFRAC' types <class 'float'> and <class 'float'>, choosing FILLFACTOR_INFRAC=0.7773609646472426 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d-99_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d-99_VOLFRAC=0.4505233802861409 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d-99_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d-99_TIERMEDd8=0.04843349767867688 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d0_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d0_VOLFRAC=0.2698145851273098 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d0_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d0_TIERMEDd8=-0.9141583421061842 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d1_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d1_VOLFRAC=0.1713053301838349 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d1_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d1_TIERMEDd8=-0.222991941693536 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d2_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d2_VOLFRAC=0.09536739321067143 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d2_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d2_TIERMEDd8=1.044252920198578 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d3_VOLFRAC' types <class 'float'> and <class 'float'>, choosing DDP1_d3_VOLFRAC=0.01298931119204304 [astropy.utils.metadata]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DDP1_d3_TIERMEDd8' types <class 'float'> and <class 'float'>, choosing DDP1_d3_TIERMEDd8=4.970416288891117 [astropy.utils.metadata]

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 30))

rand_d8   = rand[rand['FIELD'] == field]

gama_d8_slice = gama_d8[np.abs(gama_d8['CARTESIAN_Z']) < 5.]
rand_d8_slice = rand_d8[np.abs(rand_d8['CARTESIAN_Z']) < 5.]

for idx in range(3):
    # rand_d8_slice['DDP{}_DELTA8'.format(idx+1)]
    
    sc = axes[idx].scatter(rand_d8_slice['CARTESIAN_X'],\
                           rand_d8_slice['CARTESIAN_Y'],\
                           c='k',\
                           alpha=0.05,\
                           marker='.',\
                           lw=0.0,\
                           s=3,\
                           vmin=-1.,\
                           vmax=10.)
    
    sc = axes[idx].scatter(gama_d8_slice['CARTESIAN_X'],\
                           gama_d8_slice['CARTESIAN_Y'],\
                           c=gama_d8_slice['DDP{}_DELTA8'.format(idx+1)],\
                           alpha=1.,\
                           marker='.',\
                           lw=0.0,\
                           s=3,\
                           vmin=-1.,\
                           vmax=10.)
    
    
    axes[idx].set_ylim(100., -100.)
    
    colorbar = fig.colorbar(sc, ax=axes[idx], label=r'$\delta_8$')    
    
    axes[idx].set_xlabel('x [Mpc/h]')
    axes[idx].set_ylabel('y [Mpc/h]')
    
    axes[idx].set_title('DDP{}'.format(idx+1))

# %%
rand['Z'].min(), rand['Z'].max()
# Out:
# (0.03900268, 0.26299992)

# %%
gama_d8.meta
# Out:
# OrderedDict([('EXTNAME', 'TilingCat'),
#              ('TCOMM1', 'GAMA ID'),
#              ('TUCD1', 'meta.id;meta.main'),
#              ('TCOMM2', 'SDSS objid'),
#              ('TUCD2', 'meta.id'),
#              ('TCOMM3', 'J2000 coordinate'),
#              ('TUCD3', 'pos.eq.ra'),
#              ('TCOMM4', 'J2000 coordinate'),
#              ('TUCD4', 'pos.eq.dec'),
#              ('TCOMM5', '3-arcsec fiber magnitude'),
#              ('TUCD5', 'phot.mag;em.opt.R'),
#              ('TCOMM6', 'Extinction-corrected SDSS DR7 Petrosian mag'),
#              ('TUCD6', 'phot.mag;em.opt.R'),
#              ('TCOMM7', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD7', 'phot.mag;em.opt.U'),
#              ('TCOMM8', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD8', 'phot.mag;em.opt.B'),
#              ('TCOMM9', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD9', 'phot.mag;em.opt.R'),
#              ('TCOMM10', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD10', 'phot.mag;em.opt.I'),
#              ('TCOMM11', 'Extinction-corrected SDSS DR7 mag'),
#              ('TUCD11', 'phot.mag;em.opt.I'),
#              ('TCOMM12', 'Survey code for redshift source, see notes'),
#              ('TUCD12', 'meta.code;meta.dataset'),
#              ('TCOMM13', 'Spectroscopic redshift, -1 for none attempted'),
#              ('TUCD13', 'src.redshift'),
#              ('TCOMM14', 'Quality of redshift'),
#              ('TUCD14', 'meta.code.qual;src.redshift'),
#              ('TCOMM15', 'Tests of NQ=2 redshifts, see notes'),
#              ('TUCD15', 'meta.code.qual;src.redshift'),
#              ('TCOMM16', 'ID of spectrum from SpecAll table'),
#              ('TUCD16', 'meta.id.cross;spect'),
#              ('TCOMM17', 'Redshift uncertainty, c delta ln(1+z), see notes'),
#              ('TUCD17', 'src.redshift;stat.error'),
#              ('TCOMM18', 'Number of GAMA spectra within 1 arcsec'),
#              ('TUCD18', 'meta.number;spect'),
#              ('TCOMM19', 'SDSS Petro half-light surface brightness'),
#              ('TUCD19', 'phot.mag.sb;em.opt.R'),
#              ('TCOMM20', 'r_psf - r_model star-galaxy separation parameter'),
#              ('TUCD20', 'src.class.starGalaxy'),
#              ('TCOMM21', 'J - K - f_locus star-galaxy separation parameter'),
#              ('TUCD21', 'src.class.starGalaxy'),
#              ('TCOMM22', 'Extinction-corrected r-defined auto AB mag'),
#              ('TUCD22', 'phot.mag;em.IR.K'),
#              ('TCOMM23', 'Flux from FIRST-SDSS matching by John Ching'),
#              ('TUCD23', 'phot.flux.density;em.radio'),
#              ('TCOMM24', '1 for match to H-ATLAS SDSS possible ID'),
#              ('TUCD24', 'meta.code'),
#              ('TCOMM25', '1-deg strip, 2 for GAMA I regions'),
#              ('TUCD25', 'meta.code'),
#              ('TCOMM26', 'Bitwise target criteria, see notes'),
#              ('TUCD26', 'meta.code'),
#              ('TCOMM27', 'Useful for selecting samples, see notes'),
#              ('TUCD27', 'meta.code.class'),
#              ('TCOMM28', 'Useful for selecting samples, see notes'),
#              ('TUCD28', 'meta.code.class'),
#              ('TCOMM29', 'Priorities for targeting, see notes'),
#              ('TUCD29', 'meta.code.class'),
#              ('TCOMM30', 'Number of survey_class>=3 targets within 40 arcsec'),
#              ('TUCD30', 'meta.code.class'),
#              ('TCOMM31', 'CATAID of object in TilingCatv11, see notes'),
#              ('TUCD31', 'meta.code.cross'),
#              ('TCOMM32', 'Mask value 0.0 to 1.0 around V<10 stars'),
#              ('TUCD32', 'meta.code'),
#              ('TCOMM33', 'Mask value 0.0 to 1.0 around V<12 stars'),
#              ('TUCD33', 'meta.code'),
#              ('TCOMM34', 'Visual classification, see notes'),
#              ('TUCD34', 'mata.code.qual'),
#              ('TCOMM35', 'Initials of classifiers, xxx for none'),
#              ('TUCD35', 'meta.id'),
#              ('DATE-HDU', '2015-09-04T13:22:37'),
#              ('STILVERS', '3.0-8'),
#              ('STILCLAS', 'uk.ac.starlink.votable.FitsPlusTableWriter'),
#              ('DMU', 'EqInputCat'),
#              ('NAME', 'TilingCat'),
#              ('VERSION', 'v46'),
#              ('DATE', '2015-05-22'),
#              ('CONTACT', 'Ivan Baldry <i.baldry@ljmu.ac.uk>'),
#              ('AREA', 180.0),
#              ('GOLD_NGAL', 113687),
#              ('DDP1_ZMIN', 0.0390699990093708),
#              ('DDP1_ZMAX', 0.2629899978637695),
#              ('DDP1_VZ', 7594754.153764196),
#              ('DDP1_NGAL', 45889),
#              ('DDP1_DENS', 0.006042196899455394),
#              ('DDP2_ZMIN', 0.03914999961853027),
#              ('DDP2_ZMAX', 0.1937000006437302),
#              ('DDP2_VZ', 3156659.558717707),
#              ('DDP2_NGAL', 32698),
#              ('DDP2_DENS', 0.01035841825568372),
#              ('DDP3_ZMIN', 0.03903000056743622),
#              ('DDP3_ZMAX', 0.1015800014138222),
#              ('DDP3_VZ', 457819.2340050841),
#              ('DDP3_NGAL', 8748),
#              ('DDP3_DENS', 0.01910797832470021),
#              ('TMR_DDP1', '[-21.8, -20.1]'),
#              ('TMR_DDP2', '[-20.6, -19.3]'),
#              ('TMR_DDP3', '[-21.8, -20.1]'),
#              ('RPATH_0',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G9_0.fits'),
#              ('RPATH_1',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G12_0.fits'),
#              ('RPATH_2',
#               '/cosma/home/durham/dc-wils7/data/GAMA4/randoms//randoms_ddp1_bd_G15_0.fits'),
#              ('VOL8', 2144.660584850632),
#              ('comments',
#               ['Science targets and information for tiling and spectroscopic',
#                'observation.'])])

# %%
np.unique(rand['FIELD'], return_counts=True)
# Out:
# (<Column name='FIELD' dtype='bytes4' length=3>
#  G12
#  G15
#   G9,
#  array([1265955, 1265955, 1265955]))

# %%
tiers = delta8_tier(gama_d8['DDP1_DELTA8'])

# %%
np.unique(tiers, return_counts=True)
# Out:
# (array([-99,   0,   1,   2,   3]), array([19096,  1302,  4021,  7860,  2081]))

# %%
realz  = 0
rpaths = [os.environ['HOME'] + '/data/GAMA4/randoms/randoms_G{}_{:d}.fits'.format(ff, realz) for ff in [9, 12, 15]]

print('Reading: {}'.format(rpaths))

rand   = None

for rpath in rpaths:
    if not os.path.isfile(rpath):
        raise  RuntimeError('Expect random bound dist. file for {}; Run bound_dist.py for this field'.format(rpath))

    if rand == None:
        rand = Table.read(rpath)

    else:
        rand = vstack([rand, Table.read(rpath)])
# Out:
# Reading: ['/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_G9_0.fits', '/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_G12_0.fits', '/cosma/home/durham/dc-moor2/data/GAMA4/randoms/randoms_G15_0.fits']

# %%
for field in ['G9', 'G12', 'G15']:
    in_field = rand[rand['FIELD'] == field]
    
    # pl.plot(rand['RANDOM_RA'], rand['RANDOM_DEC'], marker=',', lw=0.0)
    
    pl.hist(in_field['CARTESIAN_X'], histtype='step', bins=np.arange(0., 900., 10.))
        
    print(field)
    print(np.sort(in_field['CARTESIAN_X'].data).min(), np.sort(in_field['CARTESIAN_X']).max())
    print(np.sort(in_field['CARTESIAN_Y'].data).min(), np.sort(in_field['CARTESIAN_X']).max())
    print(np.sort(in_field['CARTESIAN_Z'].data).min(), np.sort(in_field['CARTESIAN_X']).max())
    print()
# Out:
# G9
# -580.43097 -73.76151
# 73.60615 -73.76151
# -26.05787 -73.76151
#
# G12
# -747.16486 -115.565475
# -78.02824 -115.565475
# -39.08608 -115.565475
#
# G15
# -636.78845 -84.78161
# -514.0881 -84.78161
# -26.05787 -84.78161

# %%
rand.dtype.names
# Out:
# ('RANDOM_RA',
#  'RANDOM_DEC',
#  'Z',
#  'V',
#  'RANDID',
#  'FIELD',
#  'CARTESIAN_X',
#  'CARTESIAN_Y',
#  'CARTESIAN_Z',
#  'IS_BOUNDARY')

# %% [markdown]
# # Done.
